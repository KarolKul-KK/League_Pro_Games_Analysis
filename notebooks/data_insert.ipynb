# %%
import sqlite3
from sqlite3 import Error
import pandas as pd
import numpy as np
import os

# %%
def create_connection(db_file: str) -> sqlite3.Connection:

    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn

# %%
def general_data_insert(conn: sqlite3.Connection, general_data: pd.DataFrame) -> None:

    sql = ''' INSERT INTO General_Data(
              Match_id,
              Date, 
              Blue_Team, 
              Red_Team, 
              Tournament, 
              Time, 
              Game_Version)
              VALUES(?, ?, ?, ?, ?, ?, ?) '''
    cur = conn.cursor()
    cur.execute(sql, general_data)
    conn.commit()
    return cur.lastrowid

# %%
def players_stats_insert(conn: sqlite3.Connection, players_data: pd.DataFrame) -> None:

    sql = ''' INSERT INTO Players_Stats(
              Player_Nickname,
              KDA,
              CS,
              Damage_Distribution,
              Gold_Distribution,
              Champion,
              Role,
              Match_id,
              Match_count)
              VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?) '''
    cur = conn.cursor()
    cur.execute(sql, players_data)
    conn.commit()
    return cur.lastrowid

# %%
def team_stats_insert(conn: sqlite3.Connection, teams_data: pd.DataFrame) -> None:

    sql =  """
            Insert into Team_Stats(
              Club_Name,
              Result,
              Kills,
              First_Blood,
              Towers,
              First_Tower,
              Dragons,
              Barons,
              Gold,
              Ban_1,
              Ban_2,
              Ban_3,
              Ban_4,
              Ban_5,
              Pick_1,
              Pick_2,
              Pick_3,
              Pick_4,
              Pick_5,
              match_id,
              match_count
            )   
            VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
          """
    cur = conn.cursor()
    cur.execute(sql, teams_data)
    conn.commit()
    return cur.lastrowid

# %%
path = os.path.normpath(os.getcwd() + os.sep + os.pardir)
conn = create_connection(os.path.join(path, "LEAGUE_PRO_GAMES_ANALYSIS/data", "league.db"))
sqlite3.register_adapter(np.int64, lambda val: int(val))

# %%
def string_to_list(string: str) -> list:
    return string.replace('[', '').replace(']', '').replace("'", '').split(',')

# %%
# General data insert
for i in range(5):
    df_general = pd.read_csv(os.path.join(path, "LEAGUE_PRO_GAMES_ANALYSIS/data/raw", f"general_data_{i}.csv"), index_col=0)
    for i in range(len(df_general)):
        general_data_insert(conn, df_general.iloc[i])

# %%
# Team stats insert
for i in range(5):
    df = pd.read_csv(os.path.join(path, "LEAGUE_PRO_GAMES_ANALYSIS/data/raw", f"right_team_stats_{i}.csv"), index_col=0)
    for i in range(len(df)):
        bans = string_to_list(df['Bans'][i])
        picks = string_to_list(df['Picks'][i])
        team_stats_insert(conn, [df['Name'][i], df['Result'][i], df['Kills'][i], df['First_Blood'][i], df['Towers'][i],
       df['First_Tower'][i], df['Dragons'][i], df['Barons'][i], df['Gold'][i], bans[0], bans[1], bans[2], bans[3], bans[4], picks[0], picks[1], picks[2], picks[3], picks[4], df['Match_id'][i],
       df['Match_count'][i]])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-61-e37fc0a27c5a> in <module>
#       1 # Team stats insert
#       2 for i in range(5):
# ----> 3     df = pd.read_csv(os.path.join(path, "LEAGUE_PRO_GAMES_ANALYSIS/data/raw", f"right_team_stats_{i}.csv"), index_col=0)
#       4     for i in range(len(df)):
#       5         bans = string_to_list(df['Bans'][i])
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2059     def read(self, nrows=None):
#    2060         try:
# -> 2061             data = self._reader.read(nrows)
#    2062         except StopIteration:
#    2063             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 14 fields in line 1711, saw 21

# %%
# Team stats insert
for i in range(5):
    df_team_stats = pd.read_csv(os.path.join(path, "LEAGUE_PRO_GAMES_ANALYSIS/data/raw", f"left_team_stats_{i}.csv"), index_col=0)
    for i in range(len(df_team_stats)):
        general_data_insert(conn, df_team_stats.iloc[i])
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-43-8832592ca5a1> in <module>
#       3     df_team_stats = pd.read_csv(os.path.join(path, "LEAGUE_PRO_GAMES_ANALYSIS/data/raw", f"left_team_stats_{i}.csv"), index_col=0)
#       4     for i in range(len(df_team_stats)):
# ----> 5         general_data_insert(conn, df_team_stats.iloc[i])
#
# <ipython-input-30-8256f299398c> in general_data_insert(conn, general_data)
#      11               VALUES(?, ?, ?, ?, ?, ?, ?) '''
#      12     cur = conn.cursor()
# ---> 13     cur.execute(sql, general_data)
#      14     conn.commit()
#      15     return cur.lastrowid
#
# ProgrammingError: Incorrect number of bindings supplied. The current statement uses 7, and there are 13 supplied.

# %%
# Player stats insert
for i in range(6):
    df_player_stats = pd.read_csv(os.path.join(path, "LEAGUE_PRO_GAMES_ANALYSIS/data/raw", f"players_stats_{i}.csv"), index_col=0)
    for i in range(len(df_player_stats)):
        players_stats_insert(conn, df_player_stats.iloc[i])

# %%
def select_all_tasks(conn: sqlite3.Connection):

    cur = conn.cursor()
    cur.execute("SELECT * FROM Players_Stats")

    rows = cur.fetchall()

    for row in rows:
        print(row)

# %%
select_all_tasks(conn)
# Out:
# ("['Tholem']", "['2/3/7']", "['239']", '18.2%', '18.9%', 'Gragas', 'Top', 39121, 0)
# ("['chef']", "['3/3/10']", "['186']", '25.8%', '19.6%', 'Hecarim', 'Jungle', 39121, 0)
# ("['Avarosa']", "['5/4/7']", "['261']", '24.3%', '22.8%', 'Ahri', 'Mid', 39121, 0)
# ("['Pako']", "['7/2/7']", "['324']", '24.4%', '26.1%', 'Jinx', 'Adc', 39121, 0)
# ("['monkaS']", "['0/5/15']", "['37']", '7.3%', '12.6%', 'Leona', 'Support', 39121, 0)
# ("['Naak', 'Nako']", "['5/2/4']", "['347']", '21.2%', '25.7%', 'Yasuo', 'Top', 39121, 0)
# ("['361efe']", "['0/5/6']", "['178']", '6.1%', '15.4%', 'Xin', 'Jungle', 39121, 0)
# ("['Kunduz']", "['5/3/9']", "['246']", '26.4%', '21.4%', 'LeBlanc', 'Mid', 39121, 0)
# ("['Ruep']", "['7/4/6']", "['318']", '38.3%', '24.4%', 'Xayah', 'Adc', 39121, 0)
# ("['Carry']", "['0/3/17']", "['25']", '8.1%', '13.2%', 'Rakan', 'Support', 39121, 0)
# ("['Naak', 'Nako']", "['8/5/2']", "['243']", '28.6%', '26.1%', 'Akshan', 'Top', 39121, 1)
# ("['361efe']", "['2/4/4']", "['156']", '9.2%', '16%', 'Xin', 'Jungle', 39121, 1)
# ("['Kunduz']", "['3/3/7']", "['314']", '17.6%', '23.4%', 'Ryze', 'Mid', 39121, 1)
# ("['Ruep']", "['2/4/6']", "['274']", '35.8%', '20.9%', 'Xayah', 'Adc', 39121, 1)
# ("['Carry']", "['1/7/8']", "['41']", '8.8%', '13.5%', 'Tahm', 'Support', 39121, 1)
# ("['Tholem']", "['3/4/4']", "['248']", '11.1%', '20.5%', 'Jax', 'Top', 39121, 1)
# ("['chef']", "['2/3/9']", "['176']", '8.9%', '16.8%', 'Viego', 'Jungle', 39121, 1)
# ("['Avarosa']", "['10/3/5']", "['266']", '35.7%', '23.2%', 'Viktor', 'Mid', 39121, 1)
# ("['Pako']", "['8/1/12']", "['343']", '39.3%', '26.8%', 'Jinx', 'Adc', 39121, 1)
# ("['monkaS']", "['0/5/14']", "['34']", '5.1%', '12.6%', 'Leona', 'Support', 39121, 1)
# ("['Naak', 'Nako']", "['6/0/7']", "['206']", '22.5%', '24.6%', 'Lee', 'Top', 39121, 2)
# ("['361efe']", "['5/0/10']", "['150']", '20.5%', '22.2%', 'Kindred', 'Jungle', 39121, 2)
# ("['Kunduz']", "['6/1/7']", "['178']", '26.4%', '21.2%', 'Syndra', 'Mid', 39121, 2)
# ("['Ruep']", "['1/2/7']", "['205']", '19.8%', '19.1%', 'Xayah', 'Adc', 39121, 2)
# ("['Carry']", "['1/4/13']", "['12']", '10.9%', '12.9%', 'Renata', 'Support', 39121, 2)
# ("['Tholem']", "['0/5/1']", "['160']", '18%', '18.5%', 'Malphite', 'Top', 39121, 2)
# ("['chef']", "['2/2/3']", "['119']", '14%', '20%', 'Hecarim', 'Jungle', 39121, 2)
# ("['Avarosa']", "['0/4/2']", "['177']", '32.3%', '19.9%', 'Viktor', 'Mid', 39121, 2)
# ("['Pako']", "['4/3/1']", "['205']", '29.2%', '26.8%', 'Jinx', 'Adc', 39121, 2)
# ("['monkaS']", "['1/5/4']", "['29']", '6.5%', '14.9%', 'Leona', 'Support', 39121, 2)
# ("['Naak', 'Nako']", "['5/0/3']", "['189']", '27.7%', '20.8%', 'Aatrox', 'Top', 39121, 3)
# ("['361efe']", "['2/3/9']", "['134']", '13.1%', '17.6%', 'Lee', 'Jungle', 39121, 3)
# ("['Kunduz']", "['2/0/4']", "['224']", '15.5%', '20%', 'Syndra', 'Mid', 39121, 3)
# ("['Ruep']", "['11/0/3']", "['225']", '37.6%', '28%', 'Kaisa', 'Adc', 39121, 3)
# ("['Carry']", "['1/3/12']", "['29']", '6.2%', '13.6%', 'Leona', 'Support', 39121, 3)
# ("['Tholem']", "['1/4/1']", "['169']", '32.8%', '21.3%', 'Camille', 'Top', 39121, 3)
# ("['chef']", "['1/6/2']", "['97']", '16.9%', '18.6%', 'Xin', 'Jungle', 39121, 3)
# ("['Avarosa']", "['0/3/3']", "['214']", '24.4%', '21.9%', 'Viktor', 'Mid', 39121, 3)
# ("['Pako']", "['4/3/1']", "['184']", '18.7%', '25%', 'Jinx', 'Adc', 39121, 3)
# ("['monkaS']", "['0/5/4']", "['30']", '7.1%', '13.3%', 'Nautilus', 'Support', 39121, 3)
# ("['Eyliph']", "['4/1/8']", "['220']", '24.4%', '23.1%', 'Gnar', 'Top', 39041, 0)
# ("['Viking']", "['5/2/10']", "['141']", '14.4%', '20%', 'Volibear', 'Jungle', 39041, 0)
# ("['Backlund']", "['5/3/9']", "['226']", '27.6%', '20.9%', 'Akali', 'Mid', 39041, 0)
# ("['Venzer']", "['3/2/7']", "['271']", '25.7%', '23%', 'Jinx', 'Adc', 39041, 0)
# ("['FGG']", "['2/1/7']", "['35']", '7.9%', '13.1%', 'Nautilus', 'Support', 39041, 0)
# ("['Kektz']", "['1/5/3']", "['154']", '15.2%', '18.3%', 'Malphite', 'Top', 39041, 0)
# ("['MC']", "['2/4/5']", "['171']", '28.4%', '20%', 'Rumble', 'Jungle', 39041, 0)
# ("['SlowQ']", "['3/3/2']", "['240']", '22%', '24.2%', 'Irelia', 'Mid', 39041, 0)
# ("['FatihCan']", "['3/3/2']", "['241']", '24.5%', '24.4%', 'Jhin', 'Adc', 39041, 0)
# ("['Nukes']", "['0/4/4']", "['37']", '9.9%', '13%', 'Sett', 'Support', 39041, 0)
# ("['Eyliph']", "['5/0/5']", "['233']", '17.3%', '21.6%', 'Camille', 'Top', 39041, 1)
# ("['Viking']", "['2/4/15']", "['147']", '11.4%', '17.2%', 'Volibear', 'Jungle', 39041, 1)
# ("['Backlund']", "['7/2/10']", "['203']", '24.8%', '20.2%', 'Vex', 'Mid', 39041, 1)
# ("['Venzer']", "['7/1/10']", "['330']", '38.3%', '27.5%', 'Jinx', 'Adc', 39041, 1)
# ("['FGG']", "['2/2/14']", "['29']", '8.2%', '13.5%', 'Nautilus', 'Support', 39041, 1)
# ("['Kektz']", "['0/5/3']", "['210']", '23%', '18.7%', 'Gnar', 'Top', 39041, 1)
# ("['MC']", "['4/5/3']", "['205']", '28.1%', '22.6%', 'Rumble', 'Jungle', 39041, 1)
# ("['SlowQ']", "['2/3/4']", "['248']", '15.7%', '23.7%', 'Irelia', 'Mid', 39041, 1)
# ("['FatihCan']", "['3/2/3']", "['215']", '24.7%', '22.7%', 'Jhin', 'Adc', 39041, 1)
# ("['Nukes']", "['0/8/5']", "['30']", '8.5%', '12.3%', 'Leona', 'Support', 39041, 1)
# ("['Kektz']", "['1/5/2']", "['136']", '21.7%', '20.5%', 'Ornn', 'Top', 39041, 2)
# ("['MC']", "['0/8/2']", "['133']", '19.9%', '19.6%', 'Xin', 'Jungle', 39041, 2)
# ("['SlowQ']", "['2/4/0']", "['189']", '28.4%', '24.3%', 'LeBlanc', 'Mid', 39041, 2)
# ("['FatihCan']", "['0/3/2']", "['175']", '15.4%', '21.2%', 'Jinx', 'Adc', 39041, 2)
# ("['Nukes']", "['0/3/2']", "['31']", '14.5%', '14.5%', 'Karma', 'Support', 39041, 2)
# ("['Eyliph']", "['3/1/6']", "['199']", '19.7%', '19.6%', 'Aatrox', 'Top', 39041, 2)
# ("['Viking']", "['6/1/7']", "['137']", '14.9%', '18.6%', 'Lee', 'Jungle', 39041, 2)
# ("['Backlund']", "['4/0/10']", "['221']", '14.3%', '21.5%', 'Ryze', 'Mid', 39041, 2)
# ("['Venzer']", "['6/0/9']", "['217']", '25.5%', '23.3%', 'Caitlyn', 'Adc', 39041, 2)
# ("['FGG']", "['4/1/11']", "['20']", '25.5%', '16.9%', 'Lux', 'Support', 39041, 2)
# ("['Myrwn']", "['2/1/7']", "['259']", '23%', '19%', 'Karma', 'Top', 38995, 0)
# ("['Albetrayber']", "['4/0/9']", "['179']", '17%', '20.1%', 'Xin', 'Jungle', 38995, 0)
# ("['Random']", "['3/1/2']", "['313']", '18.2%', '21.1%', 'Syndra', 'Mid', 38995, 0)
# ("['Guubi']", "['9/1/6']", "['296']", '34.4%', '26.9%', 'Aphelios', 'Adc', 38995, 0)
# ("['Oscure']", "['2/1/11']", "['32']", '7.4%', '13%', 'Rakan', 'Support', 38995, 0)
# ("['SLT']", "['0/5/2']", "['264']", '19.9%', '20.8%', 'Gnar', 'Top', 38995, 0)
# ("['Koldo']", "['1/3/1']", "['157']", '10.3%', '18.3%', 'Hecarim', 'Jungle', 38995, 0)
# ("['Hatrixx']", "['3/3/0']", "['260']", '44.3%', '22.9%', 'Kaisa', 'Mid', 38995, 0)
# ("['Rafitta']", "['0/5/0']", "['342']", '22.9%', '25.1%', 'Jinx', 'Adc', 38995, 0)
# ("['Seaz']", "['0/4/0']", "['51']", '2.6%', '12.8%', 'Leona', 'Support', 38995, 0)
# ("['Myrwn']", "['1/0/9']", "['220']", '23.2%', '17.9%', 'Karma', 'Top', 38995, 1)
# ("['Albetrayber']", "['5/1/5']", "['159']", '17%', '18.5%', 'Xin', 'Jungle', 38995, 1)
# ("['Random']", "['5/2/8']", "['338']", '30.1%', '28%', 'Irelia', 'Mid', 38995, 1)
# ("['Guubi']", "['5/3/5']", "['262']", '23.7%', '22.4%', 'Aphelios', 'Adc', 38995, 1)
# ("['Oscure']", "['2/2/11']", "['34']", '6%', '13.1%', 'Leona', 'Support', 38995, 1)
# ("['SLT']", "['1/4/1']", "['210']", '14.6%', '18.8%', 'Gnar', 'Top', 38995, 1)
# ("['Koldo']", "['4/4/3']", "['191']", '22.5%', '21.8%', 'Diana', 'Jungle', 38995, 1)
# ("['Hatrixx']", "['0/6/5']", "['223']", '33.2%', '19%', 'Viktor', 'Mid', 38995, 1)
# ("['Rafitta']", "['3/1/5']", "['312']", '24%', '27.1%', 'Jinx', 'Adc', 38995, 1)
# ("['Seaz']", "['0/3/8']", "['41']", '5.7%', '13.4%', 'Nautilus', 'Support', 38995, 1)
# ("['Myrwn']", "['1/2/7']", "['277']", '19.8%', '19.3%', 'Gwen', 'Top', 38995, 2)
# ("['Albetrayber']", "['3/4/8']", "['131']", '8.7%', '16.2%', 'Trundle', 'Jungle', 38995, 2)
# ("['Random']", "['5/3/7']", "['277']", '31.3%', '24.1%', 'Karthus', 'Mid', 38995, 2)
# ("['Guubi']", "['8/4/6']", "['324']", '32.9%', '28.2%', 'Jinx', 'Adc', 38995, 2)
# ("['Oscure']", "['0/3/14']", "['35']", '7.4%', '12.2%', 'Nautilus', 'Support', 38995, 2)
# ("['SLT']", "['3/4/3']", "['312']", '17.7%', '22.6%', 'Tryndamere', 'Top', 38995, 2)
# ("['Koldo']", "['1/3/7']", "['162']", '11.6%', '16.4%', 'Volibear', 'Jungle', 38995, 2)
# ("['Hatrixx']", "['5/2/10']", "['281']", '33.8%', '23.9%', 'Ahri', 'Mid', 38995, 2)
# ("['Rafitta']", "['6/4/2']", "['304']", '28.9%', '24.1%', 'Aphelios', 'Adc', 38995, 2)
# ("['Seaz']", "['1/4/9']", "['41']", '8.1%', '13%', 'Tahm', 'Support', 38995, 2)
# ("['Draptix']", "['3/5/3']", "['257']", '25.1%', '21.7%', 'Gwen', 'Top', 38985, 0)
# ("['Vichen']", "['2/4/5']", "['183']", '10.4%', '19.2%', 'Lee', 'Jungle', 38985, 0)
# ("['Pak']", "['2/1/7']", "['296']", '28.5%', '23.1%', 'Ahri', 'Mid', 38985, 0)
# ("['Jujutw0']", "['3/2/3']", "['305']", '31.9%', '22.9%', 'Lucian', 'Adc', 38985, 0)
# ("['Helaz']", "['0/7/7']", "['38']", '4.1%', '13.1%', 'Nautilus', 'Support', 38985, 0)
# ("['TamoZ']", "['2/2/4']", "['254']", '27.9%', '19.2%', 'Kennen', 'Top', 38985, 0)
# ("['Kituruken']", "['10/3/7']", "['178']", '18%', '23.1%', 'Viego', 'Jungle', 38985, 0)
# ("['Evaan']", "['4/1/9']", "['275']", '17.9%', '22.2%', 'Veigar', 'Mid', 38985, 0)
# ("['Gotzy']", "['3/1/13']", "['292']", '28.4%', '22.7%', 'Xayah', 'Adc', 38985, 0)
# ("['Wixo0']", "['0/3/16']", "['38']", '7.8%', '12.7%', 'Braum', 'Support', 38985, 0)
# ("['TamoZ']", "['3/3/4']", "['200']", '21.4%', '21.4%', 'Sett', 'Top', 38985, 1)
# ("['Kituruken']", "['4/2/12']", "['160']", '19.2%', '19.2%', 'Viego', 'Jungle', 38985, 1)
# ("['Evaan']", "['7/1/10']", "['231']", '22.4%', '22.9%', 'Veigar', 'Mid', 38985, 1)
# ("['Gotzy']", "['5/3/13']", "['241']", '30%', '22.2%', 'Jinx', 'Adc', 38985, 1)
# ("['Wixo0']", "['3/3/16']", "['24']", '7%', '14.2%', 'Rakan', 'Support', 38985, 1)
# ("['Draptix']", "['2/2/8']", "['179']", '20.5%', '19.9%', 'Sion', 'Top', 38985, 1)
# ("['Vichen']", "['1/5/6']", "['162']", '11.6%', '18.1%', 'Lee', 'Jungle', 38985, 1)
# ("['Pak']", "['6/4/3']", "['243']", '22.6%', '25.6%', 'Ahri', 'Mid', 38985, 1)
# ("['Jujutw0']", "['3/5/5']", "['238']", '39.9%', '23.6%', 'Xayah', 'Adc', 38985, 1)
# ("['Helaz']", "['0/6/5']", "['36']", '5.4%', '12.7%', 'Leona', 'Support', 38985, 1)
# ("['TamoZ']", "['2/4/10']", "['268']", '17.8%', '20.1%', 'Chogath', 'Top', 38985, 2)
# ("['Kituruken']", "['4/2/7']", "['179']", '14.8%', '19.4%', 'Viego', 'Jungle', 38985, 2)
# ("['Evaan']", "['9/2/8']", "['314']", '44.3%', '25.6%', 'Viktor', 'Mid', 38985, 2)
# ("['Gotzy']", "['3/1/7']", "['316']", '17.9%', '21.5%', 'Jinx', 'Adc', 38985, 2)
# ("['Wixo0']", "['1/2/16']", "['36']", '5.2%', '13.4%', 'Rakan', 'Support', 38985, 2)
# ("['Draptix']", "['1/4/6']", "['226']", '14%', '19.6%', 'Ornn', 'Top', 38985, 2)
# ("['Vichen']", "['4/5/4']", "['170']", '11.7%', '18.9%', 'Xin', 'Jungle', 38985, 2)
# ("['Pak']", "['3/2/4']", "['298']", '36.3%', '23.9%', 'Kaisa', 'Mid', 38985, 2)
# ("['Jujutw0']", "['2/2/4']", "['346']", '33.7%', '24.9%', 'Xayah', 'Adc', 38985, 2)
# ("['Helaz']", "['1/6/5']", "['35']", '4.3%', '12.7%', 'Nautilus', 'Support', 38985, 2)
# ("['Photon']", "['7/0/8']", "['260']", '25.7%', '26%', 'Renekton', 'Top', 39025, 0)
# ("['Forest']", "['3/4/10']", "['197']", '18.4%', '20.3%', 'Kindred', 'Jungle', 39025, 0)
# ("['TolanD']", "['5/3/13']", "['249']", '20.4%', '21.8%', 'Ryze', 'Mid', 39025, 0)
# ("['Trigger']", "['5/2/7']", "['241']", '27.3%', '20.5%', 'Aphelios', 'Adc', 39025, 0)
# ("['Kabbie']", "['0/2/8']", "['28']", '8.2%', '11.4%', 'Nautilus', 'Support', 39025, 0)
# ("['DnDn']", "['1/3/2']", "['188']", '24%', '18.5%', 'Ornn', 'Top', 39025, 0)
# ("['Sylvie']", "['2/6/5']", "['142']", '12.8%', '17.7%', 'Hecarim', 'Jungle', 39025, 0)
# ("['FIESTA']", "['2/5/6']", "['231']", '22.8%', '21.8%', 'Orianna', 'Mid', 39025, 0)
# ("['Vital']", "['3/2/5']", "['269']", '26.7%', '26.1%', 'Xayah', 'Adc', 39025, 0)
# ("['Blessing']", "['3/4/5']", "['40']", '13.8%', '15.9%', 'Sett', 'Support', 39025, 0)
# ("['DnDn']", "['1/1/8']", "['283']", '15.6%', '18.7%', 'Sion', 'Top', 39025, 1)
# ("['Sylvie']", "['5/2/9']", "['159']", '14.5%', '17.3%', 'Viego', 'Jungle', 39025, 1)
# ("['FIESTA']", "['3/3/13']", "['337']", '35.3%', '23.5%', 'Corki', 'Mid', 39025, 1)
# ("['Vital']", "['13/1/3']", "['361']", '28.2%', '28%', 'Aphelios', 'Adc', 39025, 1)
# ("['Blessing']", "['0/2/18']", "['35']", '6.4%', '12.5%', 'Braum', 'Support', 39025, 1)
# ("['Photon']", "['1/4/3']", "['306']", '18.8%', '20.5%', 'Aatrox', 'Top', 39025, 1)
# ("['Forest']", "['3/6/4']", "['197']", '16.1%', '18.9%', 'Lee', 'Jungle', 39025, 1)
# ("['TolanD']", "['1/3/6']", "['314']", '20.9%', '21.5%', 'Ryze', 'Mid', 39025, 1)
# ("['Trigger']", "['3/4/6']", "['355']", '36.2%', '25.8%', 'Xayah', 'Adc', 39025, 1)
# ("['Kabbie']", "['1/5/7']", "['42']", '8%', '13.4%', 'Nautilus', 'Support', 39025, 1)
# ("['Photon']", "['5/2/5']", "['231']", '18.9%', '21.3%', 'Renekton', 'Top', 39025, 2)
# ("['Forest']", "['4/1/13']", "['135']", '15.8%', '18.5%', 'Volibear', 'Jungle', 39025, 2)
# ("['TolanD']", "['12/2/7']", "['183']", '34.9%', '23.2%', 'Akali', 'Mid', 39025, 2)
# ("['Trigger']", "['5/0/9']", "['257']", '20.1%', '24.3%', 'Jinx', 'Adc', 39025, 2)
# ("['Kabbie']", "['2/0/12']", "['28']", '10.2%', '12.6%', 'Nautilus', 'Support', 39025, 2)
# ("['DnDn']", "['1/4/0']", "['153']", '19.1%', '19%', 'Ornn', 'Top', 39025, 2)
# ("['Sylvie']", "['3/8/2']", "['104']", '22.9%', '20.7%', 'Viego', 'Jungle', 39025, 2)
# ("['FIESTA']", "['1/5/1']", "['202']", '32.7%', '25.2%', 'Viktor', 'Mid', 39025, 2)
# ("['Vital']", "['0/5/1']", "['195']", '13.7%', '21.8%', 'Aphelios', 'Adc', 39025, 2)
# ("['Blessing']", "['0/6/3']", "['29']", '11.6%', '13.4%', 'Sett', 'Support', 39025, 2)
# ("['DnDn']", "['3/3/7']", "['270']", '21.1%', '21.4%', 'Gragas', 'Top', 39025, 3)
# ("['Sylvie']", "['3/0/10']", "['168']", '15.5%', '18.4%', 'Hecarim', 'Jungle', 39025, 3)
# ("['FIESTA']", "['5/0/10']", "['254']", '30.3%', '21.1%', 'Ahri', 'Mid', 39025, 3)
# ("['Vital']", "['8/1/4']", "['337']", '26%', '26.3%', 'Xayah', 'Adc', 39025, 3)
# ("['Blessing']", "['0/1/11']", "['39']", '7%', '12.8%', 'Alistar', 'Support', 39025, 3)
# ("['Photon']", "['2/4/2']", "['291']", '27.1%', '27%', 'Gnar', 'Top', 39025, 3)
# ("['Forest']", "['2/5/1']", "['176']", '20.9%', '18.5%', 'RekSai', 'Jungle', 39025, 3)
# ("['TolanD']", "['0/3/2']", "['262']", '24.3%', '19%', 'LeBlanc', 'Mid', 39025, 3)
# ("['Trigger']", "['0/5/1']", "['311']", '23.2%', '23%', 'Jinx', 'Adc', 39025, 3)
# ("['Kabbie']", "['1/2/0']", "['36']", '4.5%', '12.5%', 'Leona', 'Support', 39025, 3)
# ("['Photon']", "['6/5/4']", "['272']", '23.3%', '23.4%', 'Renekton', 'Top', 39025, 4)
# ("['Forest']", "['5/5/8']", "['179']", '17.7%', '19.2%', 'Hecarim', 'Jungle', 39025, 4)
# ("['TolanD']", "['2/1/7']", "['283']", '31.3%', '22.2%', 'Orianna', 'Mid', 39025, 4)
# ("['Trigger']", "['1/5/10']", "['302']", '18.6%', '22%', 'Jinx', 'Adc', 39025, 4)
# ("['Kabbie']", "['2/6/9']", "['31']", '9%', '13.2%', 'Nautilus', 'Support', 39025, 4)
# ("['DnDn']", "['5/4/10']", "['254']", '18.5%', '20.4%', 'Sion', 'Top', 39025, 4)
# ("['Sylvie']", "['4/2/6']", "['188']", '11.9%', '18.8%', 'Viego', 'Jungle', 39025, 4)
# ("['FIESTA']", "['6/2/11']", "['295']", '35.3%', '24%', 'LeBlanc', 'Mid', 39025, 4)
# ("['Vital']", "['6/3/8']", "['311']", '29.2%', '24.3%', 'Aphelios', 'Adc', 39025, 4)
# ("['Blessing']", "['1/5/10']", "['30']", '5.1%', '12.5%', 'Tahm', 'Support', 39025, 4)
# ("['Paz']", "['3/2/4']", "['317']", '22.1%', '22.2%', 'Graves', 'Top', 38966, 0)
# ("['Once']", "['2/0/7']", "['196']", '10.9%', '17.3%', 'Jarvan', 'Jungle', 38966, 0)
# ("['Jett']", "['0/1/7']", "['352']", '14.1%', '22%', 'Ryze', 'Mid', 38966, 0)
# ("['Honey']", "['4/0/4']", "['385']", '42%', '25.7%', 'Caitlyn', 'Adc', 38966, 0)
# ("['Enty']", "['0/1/9']", "['24']", '10.9%', '12.8%', 'Karma', 'Support', 38966, 0)
# ("['Kinatu']", "['0/2/1']", "['327']", '28.9%', '25.5%', 'Jayce', 'Top', 38966, 0)
# ("['blank']", "['3/3/1']", "['198']", '12.4%', '20.2%', 'Lee', 'Jungle', 38966, 0)
# ("['Dasher']", "['0/0/3']", "['288']", '26.3%', '20.4%', 'Ahri', 'Mid', 38966, 0)
# ("['Marble']", "['1/1/0']", "['280']", '29%', '21.3%', 'Xayah', 'Adc', 38966, 0)
# ("['Raina']", "['0/3/2']", "['41']", '3.4%', '12.6%', 'Leona', 'Support', 38966, 0)
# ("['RayFarky']", "['1/2/2']", "['171']", '19.7%', '19.5%', 'Gragas', 'Top', 38965, 0)
# ("['Flawless']", "['2/6/2']", "['134']", '19.4%', '20.1%', 'Viego', 'Jungle', 38965, 0)
# ("['Dice']", "['2/4/5']", "['207']", '24.3%', '23%', 'Sylas', 'Mid', 38965, 0)
# ("['Yuhi']", "['2/2/1']", "['214']", '27.1%', '23.6%', 'Zeri', 'Adc', 38965, 0)
# ("['Fujimoto']", "['0/9/4']", "['29']", '9.6%', '13.7%', 'Nautilus', 'Support', 38965, 0)
# ("['Ino']", "['3/1/5']", "['197']", '16.1%', '19.1%', 'Aatrox', 'Top', 38965, 0)
# ("['hachamecha']", "['5/2/8']", "['134']", '11.8%', '19%', 'Volibear', 'Jungle', 38965, 0)
# ("['Recap']", "['5/2/14']", "['225']", '27.6%', '21.4%', 'Ahri', 'Mid', 38965, 0)
# ("['Secret']", "['4/1/13']", "['171']", '19.3%', '20.8%', 'Lee', 'Adc', 38965, 0)
# ("['Ssol']", "['6/1/13']", "['37']", '25.2%', '19.8%', 'Senna', 'Support', 38965, 0)
# ("['Nap']", "['1/2/4']", "['189']", '6.4%', '17.2%', 'Camille', 'Top', 38964, 0)
# ("['Cassin']", "['5/1/17']", "['183']", '20.6%', '21.1%', 'Volibear', 'Jungle', 38964, 0)
# ("['Kaito']", "['2/2/17']", "['213']", '24.6%', '18.3%', 'Vex', 'Mid', 38964, 0)
# ("['HyBrid']", "['16/1/6']", "['287']", '37.6%', '29.2%', 'Zeri', 'Adc', 38964, 0)
# ("['Nemoh']", "['2/1/20']", "['30']", '10.8%', '14.2%', 'Nautilus', 'Support', 38964, 0)
# ("['Washidai']", "['4/5/2']", "['195']", '29.1%', '26.7%', 'Gnar', 'Top', 38964, 0)
# ("['Yunika']", "['0/6/2']", "['152']", '17.8%', '18.3%', 'Hecarim', 'Jungle', 38964, 0)
# ("['Eugeo']", "['1/3/3']", "['215']", '25.5%', '20.9%', 'Ryze', 'Mid', 38964, 0)
# ("['dresscode']", "['0/4/2']", "['211']", '16.2%', '20.6%', 'Kaisa', 'Adc', 38964, 0)
# ("['hetel']", "['1/8/2']", "['11']", '11.3%', '13.4%', 'Renata', 'Support', 38964, 0)
# ("['Evi']", "['6/1/4']", "['166']", '20.2%', '23%', 'Tryndamere', 'Top', 38963, 0)
# ("['Steal']", "['3/2/15']", "['121']", '24.7%', '19.3%', 'Xin', 'Jungle', 38963, 0)
# ("['Yaharong']", "['10/1/3']", "['196']", '28%', '24%', 'Ahri', 'Mid', 38963, 0)
# ("['Yutapon']", "['4/2/7']", "['173']", '16.2%', '20.3%', 'Jinx', 'Adc', 38963, 0)
# ("['Harp']", "['3/1/10']", "['33']", '10.9%', '13.4%', 'Tahm', 'Support', 38963, 0)
# ("['tol2']", "['0/8/1']", "['147']", '32.1%', '19.1%', 'Sejuani', 'Top', 38963, 0)
# ("['Swamp']", "['0/5/4']", "['96']", '16%', '17.1%', 'Hecarim', 'Jungle', 38963, 0)
# ("['Megumiin']", "['3/6/0']", "['165']", '20%', '24.8%', 'Syndra', 'Mid', 38963, 0)
# ("['Sangchu']", "['4/4/1']", "['168']", '24.9%', '24.8%', 'Kaisa', 'Adc', 38963, 0)
# ("['Dicey']", "['0/3/4']", "['32']", '7%', '14.2%', 'Nautilus', 'Support', 38963, 0)
# ("['BioPanther']", "['5/4/2']", "['231']", '32.3%', '23.6%', 'Tryndamere', 'Top', 38946, 0)
# ("['Maximize']", "['4/5/1']", "['150']", '16.6%', '18.3%', 'Xin', 'Jungle', 38946, 0)
# ("['Kisee']", "['2/1/7']", "['288']", '19.4%', '22.9%', 'Ryze', 'Mid', 38946, 0)
# ("['Puma']", "['3/6/6']", "['255']", '19.7%', '23.1%', 'Zeri', 'Adc', 38946, 0)
# ("['Corporal']", "['0/8/7']", "['35']", '11.9%', '12.1%', 'Nautilus', 'Support', 38946, 0)
# ("['zorenous']", "['9/4/9']", "['212']", '31.6%', '23.6%', 'Camille', 'Top', 38946, 0)
# ("['Goodo']", "['2/2/14']", "['171']", '13.7%', '17.8%', 'Volibear', 'Jungle', 38946, 0)
# ("['Kyose']", "['7/1/8']", "['278']", '28%', '23.1%', 'Vex', 'Mid', 38946, 0)
# ("['Frosts']", "['6/4/11']", "['245']", '20.7%', '22.5%', 'Lucian', 'Adc', 38946, 0)
# ("['Shinki']", "['0/3/20']", "['9']", '6%', '12.9%', 'Nami', 'Support', 38946, 0)
# ("['Tronthepom']", "['1/4/6']", "['174']", '16%', '17.1%', 'Ornn', 'Top', 38945, 0)
# ("['Meifan']", "['0/3/9']", "['162']", '12.3%', '17.2%', 'Xin', 'Jungle', 38945, 0)
# ("['Reufury']", "['3/2/4']", "['213']", '21.9%', '20.2%', 'Vex', 'Mid', 38945, 0)
# ("['Voice']", "['9/3/3']", "['299']", '41.3%', '31.3%', 'Draven', 'Adc', 38945, 0)
# ("['rocco521']", "['1/4/7']", "['31']", '8.5%', '14.3%', 'Nautilus', 'Support', 38945, 0)
# ("['Lived']", "['5/3/6']", "['238']", '28.2%', '22.1%', 'Aatrox', 'Top', 38945, 0)
# ("['SCOTT']", "['2/6/4']", "['170']", '7.5%', '17.3%', 'Lee', 'Jungle', 38945, 0)
# ("['fighto']", "['0/2/6']", "['349']", '18.5%', '21.1%', 'Ryze', 'Mid', 38945, 0)
# ("['leemas']", "['9/2/4']", "['347']", '42.1%', '27.6%', 'Aphelios', 'Adc', 38945, 0)
# ("['Lionel']", "['0/1/9']", "['35']", '3.7%', '11.8%', 'Tahm', 'Support', 38945, 0)
# ("['Thien']", "['0/3/1']", "['251']", '18.1%', '21.6%', 'Gnar', 'Top', 38944, 0)
# ("['LeeSA']", "['1/3/2']", "['201']", '12.7%', '20.4%', 'Hecarim', 'Jungle', 38944, 0)
# ("['Apii']", "['0/2/3']", "['256']", '23.2%', '20.1%', 'LeBlanc', 'Mid', 38944, 0)
# ("['Chayon']", "['2/4/1']", "['290']", '37.1%', '24.4%', 'Ezreal', 'Adc', 38944, 0)
# ("['Beats']", "['1/2/2']", "['20']", '8.9%', '13.5%', 'Karma', 'Support', 38944, 0)
# ("['Azus']", "['5/0/5']", "['251']", '31%', '23.7%', 'Camille', 'Top', 38944, 0)
# ("['N0body']", "['1/0/10']", "['142']", '8.3%', '17.2%', 'Trundle', 'Jungle', 38944, 0)
# ("['DaJeung']", "['6/2/5']", "['253']", '25.1%', '22.7%', 'Ahri', 'Mid', 38944, 0)
# ("['Piglet']", "['2/1/8']", "['338']", '28.7%', '24.2%', 'Jinx', 'Adc', 38944, 0)
# ("['Vxpir']", "['0/1/7']", "['31']", '6.8%', '12.3%', 'Nautilus', 'Support', 38944, 0)
# ("['Topoon']", "['3/4/3']", "['240']", '13%', '20.1%', 'Sylas', 'Top', 38943, 0)
# ("['Arthur']", "['2/4/6']", "['192']", '14.2%', '17.9%', 'Volibear', 'Jungle', 38943, 0)
# ("['Tally']", "['2/4/3']", "['310']", '19.5%', '21.7%', 'Ryze', 'Mid', 38943, 0)
# ("['Raes']", "['5/5/3']", "['360']", '46.1%', '27.4%', 'Xayah', 'Adc', 38943, 0)
# ("['Dragku']", "['0/7/9']", "['46']", '7.2%', '12.9%', 'Nautilus', 'Support', 38943, 0)
# ("['Winterer']", "['4/2/10']", "['261']", '26.4%', '19.7%', 'Gnar', 'Top', 38943, 0)
# ("['BalKhan']", "['7/2/13']", "['237']", '15.9%', '22.1%', 'Hecarim', 'Jungle', 38943, 0)
# ("['Yuri']", "['5/1/11']", "['351']", '36.9%', '23.6%', 'Viktor', 'Mid', 38943, 0)
# ("['Praedyth']", "['6/3/5']", "['289']", '17.6%', '21.4%', 'Jinx', 'Adc', 38943, 0)
# ("['Rogue']", "['2/4/15']", "['50']", '3.2%', '13.2%', 'Rakan', 'Support', 38943, 0)
# ("['Revenge']", "['1/5/3']", "['261']", '23.8%', '19.3%', 'Graves', 'Top', 38900, 0)
# ("['Xerxe']", "['3/4/4']", "['173']", '15%', '19.1%', 'Viego', 'Jungle', 38900, 0)
# ("['PowerOfEvil']", "['6/3/6']", "['320']", '34.1%', '27.7%', 'Cassiopeia', 'Mid', 38900, 0)
# ("['Arrow']", "['4/3/5']", "['240']", '22%', '21.6%', 'Ashe', 'Adc', 38900, 0)
# ("['Destiny']", "['0/2/9']", "['37']", '5%', '12.3%', 'Nautilus', 'Support', 38900, 0)
# ("['Huni']", "['6/1/7']", "['317']", '30.2%', '25.4%', 'Irelia', 'Top', 38900, 0)
# ("['Spica']", "['2/5/14']", "['148']", '12.5%', '17.1%', 'Jarvan', 'Jungle', 38900, 0)
# ("['Takeover']", "['3/3/7']", "['304']", '15.1%', '22.4%', 'Ryze', 'Mid', 38900, 0)
# ("['Tactical']", "['5/2/6']", "['336']", '36.7%', '23%', 'Jinx', 'Adc', 38900, 0)
# ("['Shenyi']", "['0/3/12']", "['33']", '5.6%', '12.1%', 'Alistar', 'Support', 38900, 0)
# ("['Summit']", "['6/4/8']", "['293']", '34.8%', '22.5%', 'Kennen', 'Top', 38899, 0)
# ("['Blaber']", "['6/0/12']", "['257']", '21.8%', '21.6%', 'Lee', 'Jungle', 38899, 0)
# ("['Fudge']", "['2/1/7']", "['321']", '14.7%', '20.6%', 'Syndra', 'Mid', 38899, 0)
# ("['Berserker']", "['6/0/7']", "['350']", '25.1%', '23.4%', 'Jinx', 'Adc', 38899, 0)
# ("['Winsome']", "['0/1/11']", "['41']", '3.6%', '11.8%', 'Nautilus', 'Support', 38899, 0)
# ("['Jenkins']", "['3/6/1']", "['273']", '32.2%', '24.3%', 'Gangplank', 'Top', 38899, 0)
# ("['Contractz']", "['1/4/2']", "['198']", '11.8%', '18%', 'Viego', 'Jungle', 38899, 0)
# ("['Palafox']", "['1/2/2']", "['301']", '28.1%', '21.3%', 'Viktor', 'Mid', 38899, 0)
# ("['Luger']", "['1/3/1']", "['354']", '21%', '24.7%', 'Zeri', 'Adc', 38899, 0)
# ("['Poome']", "['0/5/1']", "['35']", '7%', '11.7%', 'Alistar', 'Support', 38899, 0)
# ("['Bwipo']", "['5/4/2']", "['396']", '40.2%', '26.7%', 'Lucian', 'Top', 38898, 0)
# ("['Santorin']", "['1/2/4']", "['195']", '7.5%', '16.1%', 'Trundle', 'Jungle', 38898, 0)
# ("['Bjergsen']", "['0/2/7']", "['315']", '23.8%', '20.7%', 'Ahri', 'Mid', 38898, 0)
# ("['Hans', 'sama']", "['2/2/1']", "['415']", '26.6%', '24.1%', 'Zeri', 'Adc', 38898, 0)
# ("['CoreJJ']", "['1/2/3']", "['47']", '1.9%', '12.3%', 'Taric', 'Support', 38898, 0)
# ("['Kumo']", "['3/4/6']", "['268']", '25.8%', '20%', 'Gragas', 'Top', 38898, 0)
# ("['Josedeodo']", "['1/2/4']", "['224']", '8.1%', '17.4%', 'Viego', 'Jungle', 38898, 0)
# ("['Toucouille']", "['2/0/4']", "['349']", '30.8%', '21.9%', 'Veigar', 'Mid', 38898, 0)
# ("['Johnsun']", "['6/0/1']", "['415']", '30.5%', '28.1%', 'Tristana', 'Adc', 38898, 0)
# ("['Aphromoo']", "['0/3/2']", "['33']", '4.9%', '12.6%', 'Nautilus', 'Support', 38898, 0)
# ("['Licorice']", "['3/0/4']", "['226']", '34.1%', '20.9%', 'Fiora', 'Top', 38897, 0)
# ("['Pridestalkr']", "['6/2/7']", "['168']", '16.6%', '23.2%', 'Hecarim', 'Jungle', 38897, 0)
# ("['Ablazeolive']", "['1/0/10']", "['271']", '28.9%', '21.9%', 'Viktor', 'Mid', 38897, 0)
# ("['Lost']", "['6/3/5']", "['222']", '15.6%', '22%', 'Kaisa', 'Adc', 38897, 0)
# ("['Olleh']", "['0/5/10']", "['34']", '4.8%', '12.1%', 'Leona', 'Support', 38897, 0)
# ("['FakeGod']", "['0/2/0']", "['189']", '21.1%', '17.8%', 'Tryndamere', 'Top', 38897, 0)
# ("['River']", "['3/2/6']", "['181']", '18.1%', '22.5%', 'Lee', 'Jungle', 38897, 0)
# ("['Blue']", "['4/4/1']", "['244']", '24.7%', '22.6%', 'Sylas', 'Mid', 38897, 0)
# ("['Neo']", "['3/4/4']", "['232']", '27.5%', '23.4%', 'Aphelios', 'Adc', 38897, 0)
# ("['Biofrost']", "['0/4/8']", "['40']", '8.7%', '13.7%', 'Nautilus', 'Support', 38897, 0)
# ("['Impact']", "['0/3/5']", "['414']", '23.8%', '21.5%', 'Gnar', 'Top', 38896, 0)
# ("['Inspired']", "['2/2/8']", "['226']", '11.1%', '17.3%', 'Jarvan', 'Jungle', 38896, 0)
# ("['jojopyun']", "['1/5/5']", "['395']", '18.2%', '20.7%', 'Orianna', 'Mid', 38896, 0)
# ("['Danny']", "['7/2/1']", "['559']", '40.5%', '28.5%', 'Zeri', 'Adc', 38896, 0)
# ("['Vulcan']", "['0/4/7']", "['36']", '6.5%', '11.9%', 'Nautilus', 'Support', 38896, 0)
# ("['ssumday']", "['3/0/5']", "['531']", '20.9%', '25.8%', 'Graves', 'Top', 38896, 0)
# ("['Closer']", "['3/3/7']", "['198']", '9.1%', '15.5%', 'Volibear', 'Jungle', 38896, 0)
# ("['Abbedagge']", "['4/2/7']", "['358']", '24%', '21.8%', 'Twisted', 'Mid', 38896, 0)
# ("['FBI']", "['5/2/6']", "['507']", '40.9%', '25.2%', 'Jinx', 'Adc', 38896, 0)
# ("['Huhi']", "['1/3/8']", "['34']", '5.2%', '11.8%', 'Tahm', 'Support', 38896, 0)
# ("['Jauny']", "['2/2/0']", "['350']", '17.8%', '22.6%', 'Renekton', 'Top', 39016, 0)
# ("['SolidSnake']", "['1/2/3']", "['208']", '15.9%', '17.6%', 'Volibear', 'Jungle', 39016, 0)
# ("['cody']", "['1/6/3']", "['264']", '25.7%', '20%', 'LeBlanc', 'Mid', 39016, 0)
# ("['Kz']", "['1/2/5']", "['398']", '32.7%', '26%', 'Zeri', 'Adc', 39016, 0)
# ("['Ackerman']", "['2/2/3']", "['65']", '7.9%', '13.8%', 'Nautilus', 'Support', 39016, 0)
# ("['Lonely']", "['1/0/10']", "['340']", '21.1%', '21.7%', 'Sion', 'Top', 39016, 0)
# ("['Dimitry']", "['4/2/4']", "['226']", '13.4%', '18.6%', 'Lee', 'Jungle', 39016, 0)
# ("['Aloned']", "['2/0/10']", "['327']", '26.3%', '21.5%', 'Ahri', 'Mid', 39016, 0)
# ("['5Kid']", "['6/2/4']", "['389']", '33.7%', '25.1%', 'Xayah', 'Adc', 39016, 0)
# ("['Straight']", "['1/3/6']", "['45']", '5.6%', '13%', 'Leona', 'Support', 39016, 0)
# ("['Lonely']", "['5/3/3']", "['333']", '34%', '23.6%', 'Jayce', 'Top', 39016, 1)
# ("['Dimitry']", "['2/5/6']", "['172']", '9.9%', '16.7%', 'Volibear', 'Jungle', 39016, 1)
# ("['Aloned']", "['3/1/6']", "['310']", '17.5%', '21.4%', 'Ahri', 'Mid', 39016, 1)
# ("['5Kid']", "['6/2/6']", "['346']", '31.6%', '25%', 'Xayah', 'Adc', 39016, 1)
# ("['Straight']", "['1/3/13']", "['25']", '7%', '13.3%', 'Alistar', 'Support', 39016, 1)
# ("['Jauny']", "['2/3/8']", "['240']", '15.7%', '19.4%', 'Ornn', 'Top', 39016, 1)
# ("['SolidSnake']", "['4/2/4']", "['191']", '11.2%', '20.3%', 'Viego', 'Jungle', 39016, 1)
# ("['cody']", "['2/3/9']", "['285']", '33.4%', '21.8%', 'Azir', 'Mid', 39016, 1)
# ("['Kz']", "['6/3/5']", "['332']", '27.9%', '26.4%', 'Jinx', 'Adc', 39016, 1)
# ("['Ackerman']", "['0/6/9']", "['36']", '11.8%', '12%', 'Nautilus', 'Support', 39016, 1)
# ("['Jauny']", "['2/4/6']", "['329']", '24.5%', '22%', 'Gnar', 'Top', 39016, 2)
# ("['SolidSnake']", "['5/7/4']", "['275']", '10.8%', '19.2%', 'Lee', 'Jungle', 39016, 2)
# ("['cody']", "['4/3/6']", "['336']", '24.1%', '22.3%', 'Twisted', 'Mid', 39016, 2)
# ("['Kz']", "['3/3/5']", "['473']", '31.5%', '25%', 'Jinx', 'Adc', 39016, 2)
# ("['Ackerman']", "['0/2/8']", "['41']", '9%', '11.5%', 'Tahm', 'Support', 39016, 2)
# ("['Lonely']", "['3/6/4']", "['316']", '19.8%', '19.9%', 'Akali', 'Top', 39016, 2)
# ("['Dimitry']", "['5/2/11']", "['293']", '15.1%', '20.8%', 'Hecarim', 'Jungle', 39016, 2)
# ("['Aloned']", "['6/2/9']", "['283']", '27.8%', '19.6%', 'LeBlanc', 'Mid', 39016, 2)
# ("['5Kid']", "['5/2/3']", "['524']", '28.7%', '27%', 'Aphelios', 'Adc', 39016, 2)
# ("['Straight']", "['0/2/13']", "['20']", '8.7%', '12.7%', 'Renata', 'Support', 39016, 2)
# ("['Guigo']", "['1/4/4']", "['216']", '35.5%', '19.4%', 'Gwen', 'Top', 38937, 0)
# ("['Aegis']", "['2/3/3']", "['212']", '17.4%', '21.7%', 'Hecarim', 'Jungle', 38937, 0)
# ("['Grevthar']", "['0/4/4']", "['238']", '11.9%', '20.5%', 'Ryze', 'Mid', 38937, 0)
# ("['Titan']", "['4/4/4']", "['259']", '28.9%', '25.1%', 'Xayah', 'Adc', 38937, 0)
# ("['JoJo']", "['1/6/6']", "['36']", '6.2%', '13.3%', 'Leona', 'Support', 38937, 0)
# ("['Wizer']", "['8/0/5']", "['291']", '28.7%', '27.2%', 'Tryndamere', 'Top', 38937, 0)
# ("['Cariok']", "['2/3/11']", "['189']", '12.5%', '17.5%', 'Xin', 'Jungle', 38937, 0)
# ("['dyNquedo']", "['6/0/11']", "['239']", '24.3%', '20.3%', 'Ahri', 'Mid', 38937, 0)
# ("['Trigo']", "['5/0/8']", "['289']", '29.9%', '23%', 'Ezreal', 'Adc', 38937, 0)
# ("['Damage']", "['0/5/14']", "['42']", '4.6%', '12%', 'Nautilus', 'Support', 38937, 0)
# ("['Parang']", "['3/0/8']", "['335']", '30.5%', '24.9%', 'Gnar', 'Top', 38936, 0)
# ("['Wiz']", "['9/2/7']", "['188']", '18.8%', '20.6%', 'Lee', 'Jungle', 38936, 0)
# ("['Hauz']", "['2/3/4']", "['272']", '13.4%', '20.1%', 'Vex', 'Mid', 38936, 0)
# ("['Disave']", "['6/2/8']", "['295']", '32%', '22.5%', 'Aphelios', 'Adc', 38936, 0)
# ("['Scuro']", "['0/5/11']", "['37']", '5.3%', '11.9%', 'Nautilus', 'Support', 38936, 0)
# ("['Mito']", "['1/5/6']", "['222']", '23%', '18.5%', 'Sion', 'Top', 38936, 0)
# ("['Asta']", "['5/2/7']", "['157']", '17.6%', '20.4%', 'Xin', 'Jungle', 38936, 0)
# ("['Tutsz']", "['1/3/5']", "['288']", '26.3%', '21.9%', 'Viktor', 'Mid', 38936, 0)
# ("['Flare']", "['2/3/10']", "['290']", '26.1%', '25.9%', 'Jinx', 'Adc', 38936, 0)
# ("['Gyeong']", "['3/7/6']", "['22']", '6.9%', '13.3%', 'Leona', 'Support', 38936, 0)
# ("['DoRun']", "['7/5/4']", "['174']", '20.9%', '20.2%', 'Rumble', 'Top', 38935, 0)
# ("['Croc']", "['9/8/7']", "['173']", '20.3%', '22.4%', 'Lee', 'Jungle', 38935, 0)
# ("['Anyyy']", "['1/5/9']", "['222']", '14.9%', '20.2%', 'Sylas', 'Mid', 38935, 0)
# ("['Celo']", "['0/6/13']", "['281']", '36.8%', '23.9%', 'Jinx', 'Adc', 38935, 0)
# ("['Hawk']", "['3/7/6']", "['35']", '7.2%', '13.3%', 'Nautilus', 'Support', 38935, 0)
# ("['fNb']", "['5/7/18']", "['215']", '26.3%', '21.2%', 'Gwen', 'Top', 38935, 0)
# ("['Ranger']", "['9/5/16']", "['196']", '20.4%', '20.7%', 'Viego', 'Jungle', 38935, 0)
# ("['Envy']", "['9/2/17']", "['257']", '26.2%', '23%', 'Orianna', 'Mid', 38935, 0)
# ("['Netuno']", "['8/2/13']", "['287']", '20.2%', '22.7%', 'Zeri', 'Adc', 38935, 0)
# ("['RedBert']", "['0/4/22']", "['34']", '6.9%', '12.3%', 'Alistar', 'Support', 38935, 0)
# ("['Trap']", "['12/8/6']", "['352']", '45.3%', '28.7%', 'Jayce', 'Top', 38934, 0)
# ("['Minerva']", "['2/5/11']", "['170']", '7.8%', '16.8%', 'Trundle', 'Jungle', 38934, 0)
# ("['Goku']", "['5/6/6']", "['295']", '16.9%', '20.6%', 'Sylas', 'Mid', 38934, 0)
# ("['NinjaKiwi']", "['5/4/10']", "['328']", '25.5%', '22.8%', 'Zeri', 'Adc', 38934, 0)
# ("['Mocha']", "['0/8/10']", "['35']", '4.5%', '11%', 'Alistar', 'Support', 38934, 0)
# ("['Robo']", "['5/7/12']", "['310']", '19.6%', '22.4%', 'Tryndamere', 'Top', 38934, 0)
# ("['Tay']", "['5/4/14']", "['195']", '10.1%', '17.9%', 'Volibear', 'Jungle', 38934, 0)
# ("['Tinowns']", "['5/1/19']", "['267']", '33.5%', '21.4%', 'Ahri', 'Mid', 38934, 0)
# ("['DudsTheBoy']", "['15/5/7']", "['306']", '31%', '25.9%', 'Aphelios', 'Adc', 38934, 0)
# ("['Ceos']", "['0/7/21']", "['39']", '5.8%', '12.4%', 'Nautilus', 'Support', 38934, 0)
# ("['Kiari']", "['6/1/3']", "['215']", '23.7%', '25.2%', 'Graves', 'Top', 38933, 0)
# ("['Disamis']", "['5/1/9']", "['152']", '21.7%', '21.2%', 'Lee', 'Jungle', 38933, 0)
# ("['Krastyel']", "['2/2/11']", "['209']", '24.7%', '20.4%', 'Orianna', 'Mid', 38933, 0)
# ("['Matsukaze']", "['4/0/9']", "['192']", '20.5%', '20.7%', 'Zeri', 'Adc', 38933, 0)
# ("['Wos']", "['0/3/12']", "['27']", '9.3%', '12.5%', 'Nautilus', 'Support', 38933, 0)
# ("['Tyrin']", "['1/5/1']", "['211']", '9%', '22.7%', 'Irelia', 'Top', 38933, 0)
# ("['Yampi']", "['2/5/4']", "['131']", '14.8%', '19.9%', 'Volibear', 'Jungle', 38933, 0)
# ("['Kick']", "['1/3/1']", "['214']", '29%', '21.8%', 'Syndra', 'Mid', 38933, 0)
# ("['micaO']", "['2/3/4']", "['199']", '30.5%', '22%', 'Lucian', 'Adc', 38933, 0)
# ("['Decoy']", "['1/1/5']", "['8']", '16.7%', '13.6%', 'Yuumi', 'Support', 38933, 0)
# ("['Madly']", "['0/7/3']", "['216']", '17.6%', '18%', 'Kennen', 'Top', 39120, 0)
# ("['Elramir']", "['3/5/5']", "['211']", '26%', '21%', 'Hecarim', 'Jungle', 39120, 0)
# ("['Jool']", "['3/4/4']", "['281']", '27.1%', '23.7%', 'Ryze', 'Mid', 39120, 0)
# ("['Rhioni']", "['3/7/3']", "['276']", '23.1%', '23%', 'Jinx', 'Adc', 39120, 0)
# ("['PoP']", "['4/5/4']", "['34']", '6.1%', '14.4%', 'Alistar', 'Support', 39120, 0)
# ("['Hoon']", "['7/2/7']", "['269']", '25.3%', '21.1%', 'Sylas', 'Top', 39120, 0)
# ("['Kireas']", "['4/2/13']", "['191']", '20.4%', '19.8%', 'Xin', 'Jungle', 39120, 0)
# ("['Luka']", "['4/2/7']", "['242']", '27.7%', '20%', 'Syndra', 'Mid', 39120, 0)
# ("['Andariel']", "['11/2/5']", "['294']", '19.7%', '24.9%', 'Kalista', 'Adc', 39120, 0)
# ("['Sloth']", "['2/5/17']", "['38']", '6.9%', '14.2%', 'Nautilus', 'Support', 39120, 0)
# ("['robocop']", "['5/0/4']", "['251']", '18.3%', '24%', 'Gnar', 'Top', 39035, 0)
# ("['Rames']", "['6/2/12']", "['145']", '23.1%', '18.8%', 'Xin', 'Jungle', 39035, 0)
# ("['Eren']", "['6/1/11']", "['170']", '27.1%', '19.4%', 'Ahri', 'Mid', 39035, 0)
# ("['Khantos']", "['9/2/6']", "['204']", '21.3%', '23.8%', 'Aphelios', 'Adc', 39035, 0)
# ("['Denyk']", "['1/1/21']", "['31']", '10.2%', '14%', 'Rakan', 'Support', 39035, 0)
# ("['Welcom']", "['0/7/2']", "['188']", '28%', '19.7%', 'Graves', 'Top', 39035, 0)
# ("['Jejky']", "['1/5/3']", "['144']", '15.8%', '19.2%', 'Lee', 'Jungle', 39035, 0)
# ("['Sajator']", "['3/4/3']", "['207']", '26%', '23.9%', 'Orianna', 'Mid', 39035, 0)
# ("['Dany']", "['1/5/4']", "['192']", '22.7%', '22.7%', 'Jinx', 'Adc', 39035, 0)
# ("['Vasked']", "['1/6/4']", "['47']", '7.5%', '14.5%', 'Leona', 'Support', 39035, 0)
# ("['robocop']", "['4/2/8']", "['290']", '37%', '23.8%', 'Gnar', 'Top', 39035, 1)
# ("['Rames']", "['5/3/8']", "['178']", '11.6%', '19.2%', 'Lee', 'Jungle', 39035, 1)
# ("['Eren']", "['0/1/12']", "['282']", '20.5%', '19.9%', 'Ahri', 'Mid', 39035, 1)
# ("['Khantos']", "['6/2/5']", "['300']", '23.8%', '24.1%', 'Aphelios', 'Adc', 39035, 1)
# ("['Denyk']", "['2/2/8']", "['36']", '7.1%', '12.9%', 'Alistar', 'Support', 39035, 1)
# ("['Welcom']", "['2/5/4']", "['249']", '32.5%', '22.5%', 'Aatrox', 'Top', 39035, 1)
# ("['Jejky']", "['1/5/5']", "['207']", '15.7%', '18.4%', 'Graves', 'Jungle', 39035, 1)
# ("['Sajator']", "['4/1/4']", "['306']", '22.2%', '24.3%', 'Orianna', 'Mid', 39035, 1)
# ("['Dany']", "['3/3/2']", "['295']", '24.2%', '23.1%', 'Varus', 'Adc', 39035, 1)
# ("['Vasked']", "['0/3/5']", "['38']", '5.4%', '11.8%', 'Leona', 'Support', 39035, 1)
# ("['Welcom']", "['5/9/3']", "['194']", '24%', '22.2%', 'Jayce', 'Top', 39035, 2)
# ("['Jejky']", "['4/5/7']", "['181']", '20.4%', '20.5%', 'Hecarim', 'Jungle', 39035, 2)
# ("['Sajator']", "['2/3/12']", "['213']", '22.7%', '20.9%', 'Twisted', 'Mid', 39035, 2)
# ("['Dany']", "['5/5/8']", "['214']", '24.8%', '24.2%', 'Jhin', 'Adc', 39035, 2)
# ("['Vasked']", "['1/8/9']", "['36']", '8.2%', '12.1%', 'Leona', 'Support', 39035, 2)
# ("['robocop']", "['2/2/20']", "['169']", '24.6%', '18.8%', 'Malphite', 'Top', 39035, 2)
# ("['Rames']", "['13/2/15']", "['167']", '24.1%', '25.4%', 'Lee', 'Jungle', 39035, 2)
# ("['Eren']", "['5/5/18']", "['194']", '24.5%', '19.6%', 'Ryze', 'Mid', 39035, 2)
# ("['Khantos']", "['9/5/2']", "['201']", '17.9%', '22.5%', 'Samira', 'Adc', 39035, 2)
# ("['Denyk']", "['1/3/22']", "['39']", '8.9%', '13.6%', 'Alistar', 'Support', 39035, 2)
# ("['JaxPlank']", "['1/2/2']", "['212']", '29.1%', '23%', 'Gnar', 'Top', 38938, 0)
# ("['WRDN']", "['2/4/2']", "['136']", '15.8%', '18.1%', 'Gragas', 'Jungle', 38938, 0)
# ("['Vladi']", "['2/6/1']", "['214']", '18.4%', '22.1%', 'Yasuo', 'Mid', 38938, 0)
# ("['Lindgarde']", "['0/5/1']", "['225']", '22.7%', '23.2%', 'Jinx', 'Adc', 38938, 0)
# ("['Brolia']", "['0/6/2']", "['33']", '14.1%', '13.6%', 'Braum', 'Support', 38938, 0)
# ("['Bako']", "['2/2/4']", "['194']", '26.5%', '18.6%', 'Jayce', 'Top', 38938, 0)
# ("['NikoleX']", "['3/1/10']", "['129']", '12.2%', '18.3%', 'Volibear', 'Jungle', 38938, 0)
# ("['Peppe']", "['10/1/2']", "['193']", '26.5%', '21.4%', 'Akali', 'Mid', 38938, 0)
# ("['Vaynedeta']", "['7/0/6']", "['289']", '29.2%', '28%', 'Aphelios', 'Adc', 38938, 0)
# ("['Sanity']", "['1/1/14']", "['37']", '5.6%', '13.6%', 'Nautilus', 'Support', 38938, 0)
# ("['JaxPlank']", "['0/4/2']", "['165']", '11.9%', '19.3%', 'Jax', 'Top', 38938, 1)
# ("['WRDN']", "['3/2/5']", "['151']", '21.7%', '21.4%', 'Graves', 'Jungle', 38938, 1)
# ("['Vladi']", "['3/1/5']", "['162']", '27.1%', '19.4%', 'Sylas', 'Mid', 38938, 1)
# ("['Lindgarde']", "['5/0/5']", "['224']", '33.5%', '26.4%', 'Jinx', 'Adc', 38938, 1)
# ("['Brolia']", "['0/3/6']", "['29']", '5.8%', '13.5%', 'Leona', 'Support', 38938, 1)
# ("['Bako']", "['3/2/3']", "['169']", '29%', '21.8%', 'Kennen', 'Top', 38938, 1)
# ("['NikoleX']", "['5/2/2']", "['125']", '9.5%', '22%', 'Udyr', 'Jungle', 38938, 1)
# ("['Peppe']", "['1/1/3']", "['178']", '31.2%', '20%', 'Viktor', 'Mid', 38938, 1)
# ("['Vaynedeta']", "['0/3/5']", "['184']", '21.9%', '21.9%', 'Aphelios', 'Adc', 38938, 1)
# ("['Sanity']", "['1/3/5']", "['28']", '8.3%', '14.3%', 'Nautilus', 'Support', 38938, 1)
# ("['Bako']", "['5/4/4']", "['243']", '35.2%', '22.9%', 'Gnar', 'Top', 38938, 2)
# ("['NikoleX']", "['6/3/2']", "['173']", '13.6%', '20.3%', 'Trundle', 'Jungle', 38938, 2)
# ("['Peppe']", "['2/5/6']", "['271']", '23.6%', '20.9%', 'Ryze', 'Mid', 38938, 2)
# ("['Vaynedeta']", "['0/2/6']", "['330']", '18.5%', '22.5%', 'Tristana', 'Adc', 38938, 2)
# ("['Sanity']", "['1/3/7']", "['43']", '9.1%', '13.4%', 'Braum', 'Support', 38938, 2)
# ("['JaxPlank']", "['2/2/8']", "['303']", '10.4%', '22.9%', 'Tryndamere', 'Top', 38938, 2)
# ("['WRDN']", "['2/2/11']", "['155']", '12.9%', '16.4%', 'Viego', 'Jungle', 38938, 2)
# ("['Vladi']", "['6/2/7']", "['265']", '38.5%', '21.9%', 'Viktor', 'Mid', 38938, 2)
# ("['Lindgarde']", "['7/3/7']", "['342']", '34.7%', '27.1%', 'Jinx', 'Adc', 38938, 2)
# ("['Brolia']", "['0/5/12']", "['31']", '3.5%', '11.7%', 'Nautilus', 'Support', 38938, 2)
# ("['JaxPlank']", "['3/5/1']", "['255']", '17.2%', '22.7%', 'Darius', 'Top', 38938, 3)
# ("['WRDN']", "['1/2/6']", "['151']", '17.3%', '16.9%', 'Sejuani', 'Jungle', 38938, 3)
# ("['Vladi']", "['4/4/3']", "['252']", '39.1%', '23.3%', 'Syndra', 'Mid', 38938, 3)
# ("['Lindgarde']", "['0/5/1']", "['299']", '21.7%', '23.6%', 'Jinx', 'Adc', 38938, 3)
# ("['Brolia']", "['0/2/7']", "['35']", '4.8%', '13.5%', 'Zilean', 'Support', 38938, 3)
# ("['Bako']", "['2/2/7']", "['231']", '11.3%', '19.6%', 'Jax', 'Top', 38938, 3)
# ("['NikoleX']", "['4/1/11']", "['198']", '17.6%', '18.8%', 'Xin', 'Jungle', 38938, 3)
# ("['Peppe']", "['7/1/6']", "['341']", '35.3%', '25.3%', 'Viktor', 'Mid', 38938, 3)
# ("['Vaynedeta']", "['5/1/8']", "['284']", '27.4%', '23.1%', 'Xayah', 'Adc', 38938, 3)
# ("['Sanity']", "['0/3/15']", "['35']", '8.4%', '13.2%', 'Nautilus', 'Support', 38938, 3)
# ("['Bako']", "['1/2/13']", "['230']", '15.5%', '19.6%', 'Ornn', 'Top', 38938, 4)
# ("['NikoleX']", "['6/1/10']", "['202']", '14.1%', '20.6%', 'Hecarim', 'Jungle', 38938, 4)
# ("['Peppe']", "['4/2/8']", "['225']", '21.8%', '19.4%', 'Viktor', 'Mid', 38938, 4)
# ("['Vaynedeta']", "['11/2/10']", "['249']", '41.5%', '25.7%', 'Xayah', 'Adc', 38938, 4)
# ("['Sanity']", "['3/1/15']", "['40']", '7.2%', '14.8%', 'Nautilus', 'Support', 38938, 4)
# ("['JaxPlank']", "['2/5/3']", "['311']", '29.5%', '26.8%', 'Sett', 'Top', 38938, 4)
# ("['WRDN']", "['4/6/3']", "['190']", '12.7%', '20.3%', 'Viego', 'Jungle', 38938, 4)
# ("['Vladi']", "['1/5/5']", "['240']", '21.1%', '19.9%', 'Ryze', 'Mid', 38938, 4)
# ("['Lindgarde']", "['1/5/4']", "['262']", '28%', '20.8%', 'Ezreal', 'Adc', 38938, 4)
# ("['Brolia']", "['0/4/5']", "['32']", '8.8%', '12.2%', 'Braum', 'Support', 38938, 4)
# ("['Sacre']", "['5/0/10']", "['297']", '32.5%', '24.9%', 'Gangplank', 'Top', 38906, 0)
# ("['D4nKa']", "['3/1/10']", "['183']", '11.7%', '18.3%', 'Hecarim', 'Jungle', 38906, 0)
# ("['Escik']", "['1/2/15']", "['280']", '31.1%', '19.9%', 'Orianna', 'Mid', 38906, 0)
# ("['jinjo']", "['4/1/7']", "['308']", '20.3%', '23.9%', 'Aphelios', 'Adc', 38906, 0)
# ("['Visdom']", "['3/1/12']", "['32']", '4.5%', '13%', 'Thresh', 'Support', 38906, 0)
# ("['PRIDE']", "['0/2/1']", "['253']", '29.6%', '20.8%', 'Gnar', 'Top', 38906, 0)
# ("['Obsess']", "['1/4/2']", "['181']", '15%', '19.8%', 'Xin', 'Jungle', 38906, 0)
# ("['Special']", "['2/4/2']", "['254']", '28%', '23.2%', 'Akali', 'Mid', 38906, 0)
# ("['Kynetic']", "['1/2/3']", "['267']", '20.7%', '23.1%', 'Jhin', 'Adc', 38906, 0)
# ("['Prime']", "['1/4/1']", "['42']", '6.7%', '13.1%', 'Blitzcrank', 'Support', 38906, 0)
# ("['PRIDE']", "['1/6/7']", "['300']", '15.5%', '19.2%', 'Dr.', 'Top', 38906, 1)
# ("['Obsess']", "['2/5/7']", "['240']", '11.1%', '17.7%', 'Viego', 'Jungle', 38906, 1)
# ("['Special']", "['7/3/7']", "['321']", '29.7%', '23.8%', 'LeBlanc', 'Mid', 38906, 1)
# ("['Kynetic']", "['9/2/6']", "['372']", '37.9%', '26.9%', 'Aphelios', 'Adc', 38906, 1)
# ("['Prime']", "['1/7/10']", "['51']", '5.8%', '12.4%', 'Leona', 'Support', 38906, 1)
# ("['Sacre']", "['8/4/9']", "['308']", '23.4%', '22.7%', 'Jayce', 'Top', 38906, 1)
# ("['D4nKa']", "['3/5/14']", "['209']", '16.3%', '18.4%', 'Xin', 'Jungle', 38906, 1)
# ("['Escik']", "['7/3/10']", "['303']", '23.9%', '21.7%', 'Ahri', 'Mid', 38906, 1)
# ("['jinjo']", "['2/5/15']", "['370']", '29.5%', '23.1%', 'Xayah', 'Adc', 38906, 1)
# ("['Visdom']", "['3/3/17']", "['44']", '6.8%', '14.2%', 'Rakan', 'Support', 38906, 1)
# ("['PRIDE']", "['8/6/11']", "['376']", '28.6%', '24.1%', 'Jayce', 'Top', 38906, 2)
# ("['Obsess']", "['5/10/13']", "['226']", '14.5%', '18.1%', 'Viego', 'Jungle', 38906, 2)
# ("['Special']", "['5/7/12']", "['370']", '24.9%', '21.9%', 'Ryze', 'Mid', 38906, 2)
# ("['Kynetic']", "['12/6/10']", "['357']", '25.3%', '24.4%', 'Aphelios', 'Adc', 38906, 2)
# ("['Prime']", "['0/9/17']", "['45']", '6.7%', '11.6%', 'Nautilus', 'Support', 38906, 2)
# ("['Sacre']", "['7/6/23']", "['303']", '27.4%', '21.1%', 'Rumble', 'Top', 38906, 2)
# ("['D4nKa']", "['5/6/20']", "['189']", '14.1%', '16.5%', 'Xin', 'Jungle', 38906, 2)
# ("['Escik']", "['6/5/17']", "['339']", '17.2%', '20.7%', 'Ahri', 'Mid', 38906, 2)
# ("['jinjo']", "['19/5/11']", "['456']", '34.1%', '29.8%', 'Jhin', 'Adc', 38906, 2)
# ("['Visdom']", "['1/8/18']", "['49']", '7.2%', '11.8%', 'Sett', 'Support', 38906, 2)
# ("['Kerberos']", "['3/6/2']", "['333']", '29.8%', '23.8%', 'Graves', 'Top', 38901, 0)
# ("['Sof']", "['4/3/5']", "['216']", '14.1%', '19.2%', 'Lee', 'Jungle', 38901, 0)
# ("['HawHaw']", "['3/6/3']", "['308']", '26.7%', '20.8%', 'Ahri', 'Mid', 38901, 0)
# ("['Rharesh']", "['1/7/9']", "['349']", '23.6%', '23.7%', 'Jinx', 'Adc', 38901, 0)
# ("['Click']", "['0/6/10']", "['20']", '5.9%', '12.5%', 'Renata', 'Support', 38901, 0)
# ("['Gabbo']", "['6/1/11']", "['338']", '32.6%', '25%', 'Aatrox', 'Top', 38901, 0)
# ("['MxDragon']", "['3/3/15']", "['178']", '14.4%', '16.6%', 'Volibear', 'Jungle', 38901, 0)
# ("['XoNix']", "['8/0/10']", "['320']", '22%', '23%', 'Sylas', 'Mid', 38901, 0)
# ("['Endz']", "['7/3/11']", "['320']", '23.4%', '21.9%', 'Varus', 'Adc', 38901, 0)
# ("['Cospect']", "['4/4/13']", "['45']", '7.6%', '13.5%', 'Thresh', 'Support', 38901, 0)
# ("['Kerberos']", "['2/5/0']", "['281']", '20.8%', '23.6%', 'Fiora', 'Top', 38901, 1)
# ("['Sof']", "['1/4/6']", "['167']", '15.3%', '17.5%', 'Hecarim', 'Jungle', 38901, 1)
# ("['HawHaw']", "['7/5/2']", "['297']", '29.7%', '25.9%', 'Ekko', 'Mid', 38901, 1)
# ("['Rharesh']", "['0/3/3']", "['290']", '24%', '20.8%', 'Jinx', 'Adc', 38901, 1)
# ("['Click']", "['0/8/6']", "['34']", '10.3%', '12.2%', 'Tahm', 'Support', 38901, 1)
# ("['Gabbo']", "['11/0/4']", "['281']", '42.2%', '24.5%', 'Gnar', 'Top', 38901, 1)
# ("['MxDragon']", "['4/0/13']", "['189']", '14.5%', '19.2%', 'Trundle', 'Jungle', 38901, 1)
# ("['XoNix']", "['5/2/10']", "['235']", '24.6%', '19.6%', 'Vex', 'Mid', 38901, 1)
# ("['Endz']", "['4/5/8']", "['283']", '13.3%', '22.5%', 'Varus', 'Adc', 38901, 1)
# ("['Cospect']", "['1/3/16']", "['35']", '5.4%', '14.2%', 'Thresh', 'Support', 38901, 1)
# ("['Gabbo']", "['10/3/6']", "['175']", '26.9%', '21.1%', 'Akali', 'Top', 38901, 2)
# ("['MxDragon']", "['3/1/12']", "['159']", '13.9%', '17.4%', 'Volibear', 'Jungle', 38901, 2)
# ("['XoNix']", "['5/1/15']", "['269']", '18.5%', '22.6%', 'Ryze', 'Mid', 38901, 2)
# ("['Endz']", "['7/2/15']", "['295']", '34.3%', '25%', 'Jinx', 'Adc', 38901, 2)
# ("['Cospect']", "['3/5/14']", "['41']", '6.4%', '13.9%', 'Thresh', 'Support', 38901, 2)
# ("['Kerberos']", "['2/7/6']", "['160']", '17.3%', '18.5%', 'Karma', 'Top', 38901, 2)
# ("['Sof']", "['4/4/4']", "['160']", '15%', '21.3%', 'Viego', 'Jungle', 38901, 2)
# ("['HawHaw']", "['2/6/2']", "['240']", '17.6%', '22.9%', 'Veigar', 'Mid', 38901, 2)
# ("['Rharesh']", "['4/5/6']", "['246']", '45.6%', '24.3%', 'Aphelios', 'Adc', 38901, 2)
# ("['Click']", "['0/6/7']", "['31']", '4.5%', '13%', 'Nautilus', 'Support', 38901, 2)
# ("['Hoon']", "['10/0/7']", "['189']", '23.9%', '23.9%', 'Aatrox', 'Top', 38890, 0)
# ("['Kireas']", "['15/0/8']", "['125']", '26.1%', '23%', 'Volibear', 'Jungle', 38890, 0)
# ("['Luka']", "['6/3/14']", "['189']", '27.1%', '19.3%', 'Viktor', 'Mid', 38890, 0)
# ("['Andariel']", "['4/5/7']", "['174']", '15.7%', '18.3%', 'Lucian', 'Adc', 38890, 0)
# ("['Sloth']", "['3/4/22']", "['33']", '7.2%', '15.5%', 'Leona', 'Support', 38890, 0)
# ("['Luana']", "['0/8/0']", "['150']", '14.2%', '17%', 'Renekton', 'Top', 38890, 0)
# ("['Umut']", "['2/8/4']", "['111']", '15.3%', '18.3%', 'Hecarim', 'Jungle', 38890, 0)
# ("['Typhoon']", "['1/6/6']", "['165']", '25.2%', '20%', 'Kaisa', 'Mid', 38890, 0)
# ("['Scorth']", "['4/9/4']", "['127']", '30.6%', '23.1%', 'Sett', 'Adc', 38890, 0)
# ("['Pbd']", "['5/7/4']", "['25']", '14.7%', '21.6%', 'Senna', 'Support', 38890, 0)
# ("['Ruin']", "['2/1/8']", "['175']", '23.4%', '17.8%', 'Gragas', 'Top', 38889, 0)
# ("['Kirei']", "['3/0/10']", "['153']", '16.5%', '19.3%', 'Xin', 'Jungle', 38889, 0)
# ("['Bolulu']", "['7/0/6']", "['260']", '25.4%', '24.3%', 'Azir', 'Mid', 38889, 0)
# ("['Gravepast']", "['7/3/8']", "['247']", '25.6%', '26.2%', 'Zeri', 'Adc', 38889, 0)
# ("['Fleshy']", "['0/1/14']", "['41']", '9.1%', '12.5%', 'Nautilus', 'Support', 38889, 0)
# ("['NuQ']", "['0/6/2']", "['157']", '21.9%', '17.2%', 'Ornn', 'Top', 38889, 0)
# ("['Crash']", "['2/3/2']", "['139']", '17.9%', '20.2%', 'Hecarim', 'Jungle', 38889, 0)
# ("['FireRain']", "['1/3/3']", "['218']", '28.7%', '23.4%', 'Orianna', 'Mid', 38889, 0)
# ("['Ellam']", "['2/4/0']", "['233']", '25.8%', '26.2%', 'Jinx', 'Adc', 38889, 0)
# ("['Sparz']", "['0/3/2']", "['33']", '5.7%', '13%', 'Leona', 'Support', 38889, 0)
# ("['Skewer']", "['1/4/4']", "['200']", '20.5%', '18.5%', 'Karma', 'Top', 38888, 0)
# ("['Chl0e']", "['5/4/6']", "['156']", '18.9%', '21.9%', 'Lee', 'Jungle', 38888, 0)
# ("['SPARKLE']", "['2/5/6']", "['282']", '21.7%', '24.8%', 'Ryze', 'Mid', 38888, 0)
# ("['Hypnos']", "['2/4/5']", "['208']", '19.8%', '20%', 'Aphelios', 'Adc', 38888, 0)
# ("['Shawi', 'Katami']", "['3/7/7']", "['43']", '19.2%', '14.8%', 'Sett', 'Support', 38888, 0)
# ("['Lot']", "['3/2/8']", "['249']", '27.5%', '20.1%', 'Gwen', 'Top', 38888, 0)
# ("['BroCColi']", "['11/2/10']", "['183']", '24.8%', '22.9%', 'Xin', 'Jungle', 38888, 0)
# ("['MGX']", "['5/2/11']", "['225']", '20.1%', '21.4%', 'Azir', 'Mid', 38888, 0)
# ("['Jeyrus']", "['5/3/8']", "['271']", '20.6%', '24.1%', 'Jinx', 'Adc', 38888, 0)
# ...
# ("['UNF0RGIVEN']", "['11/4/9']", "['376']", '30.3%', '23.4%', 'Jinx', 'Adc', 35352, 3)
# ("['QUICKTIMER']", "['0/9/17']", "['44']", '6.6%', '11.7%', 'Braum', 'Support', 35352, 3)
# ("['Satorius']", "['6/7/14']", "['355']", '32.3%', '21.2%', 'Jayce', 'Top', 35352, 3)
# ("['Pridestalkr']", "['8/3/12']", "['293']", '15.5%', '20.9%', 'Xin', 'Jungle', 35352, 3)
# ("['Czekolad']", "['6/6/13']", "['377']", '24.6%', '23.2%', 'Azir', 'Mid', 35352, 3)
# ("['Gadget']", "['7/2/20']", "['393']", '23.1%', '22.2%', 'Seraphine', 'Adc', 35352, 3)
# ("['kamilius']", "['1/10/16']", "['41']", '4.6%', '12.4%', 'Leona', 'Support', 35352, 3)
# ("['IceBreaker']", "['4/5/7']", "['261']", '22.7%', '19.9%', 'Sion', 'Top', 35298, 0)
# ("['Carnage']", "['4/5/6']", "['160']", '8.7%', '18.4%', 'Trundle', 'Jungle', 35298, 0)
# ("['WaenA']", "['7/5/5']", "['276']", '30.8%', '22.2%', 'LeBlanc', 'Mid', 35298, 0)
# ("['Bananitoo']", "['3/4/8']", "['367']", '29.1%', '25.3%', 'Lucian', 'Adc', 35298, 0)
# ("['iLevi']", "['1/7/11']", "['60']", '8.7%', '14.3%', 'Rakan', 'Support', 35298, 0)
# ("['WouLou']", "['7/5/10']", "['275']", '27.5%', '22.4%', 'Jayce', 'Top', 35298, 0)
# ("['Hatred']", "['5/2/10']", "['201']", '16.4%', '18.4%', 'KhaZix', 'Jungle', 35298, 0)
# ("['Tsiperakos']", "['5/3/16']", "['225']", '28.7%', '21%', 'Zoe', 'Mid', 35298, 0)
# ("['Druxy']", "['8/2/7']", "['337']", '23.8%', '25.4%', 'Aphelios', 'Adc', 35298, 0)
# ("['iDekap']", "['1/7/13']", "['46']", '3.5%', '12.8%', 'Thresh', 'Support', 35298, 0)
# ("['Bako']", "['5/5/6']", "['154']", '18.2%', '19.4%', 'Camille', 'Top', 35297, 0)
# ("['NikoleX']", "['4/0/11']", "['153']", '19.4%', '20.2%', 'Xin', 'Jungle', 35297, 0)
# ("['Peppe']", "['7/3/6']", "['223']", '20.1%', '22.8%', 'Ryze', 'Mid', 35297, 0)
# ("['Vaynedeta']", "['6/0/8']", "['211']", '36.1%', '24.1%', 'Ezreal', 'Adc', 35297, 0)
# ("['Sanity']", "['1/3/13']", "['29']", '6.1%', '13.5%', 'Braum', 'Support', 35297, 0)
# ("['Tatuy']", "['5/6/3']", "['158']", '25.8%', '23.7%', 'Jax', 'Top', 35297, 0)
# ("['Integral']", "['2/5/7']", "['131']", '19.1%', '18.8%', 'Lee', 'Jungle', 35297, 0)
# ("['Kourosh']", "['2/4/7']", "['163']", '21.5%', '22%', 'Twisted', 'Mid', 35297, 0)
# ("['Ralf']", "['1/3/4']", "['221']", '24.7%', '21.9%', 'Miss', 'Adc', 35297, 0)
# ("['SOAP']", "['1/5/5']", "['36']", '8.9%', '13.5%', 'Galio', 'Support', 35297, 0)
# ("['JaxPlank']", "['2/4/7']", "['264']", '24.3%', '22.9%', 'Gangplank', 'Top', 35296, 0)
# ("['Dom1nant']", "['6/5/4']", "['159']", '18.4%', '18.7%', 'Akshan', 'Jungle', 35296, 0)
# ("['J0J0C']", "['4/7/8']", "['254']", '20.7%', '21.5%', 'Ryze', 'Mid', 35296, 0)
# ("['Piwek']", "['4/4/6']", "['307']", '29.7%', '24.3%', 'Miss', 'Adc', 35296, 0)
# ("['kubYD']", "['1/3/11']", "['35']", '6.9%', '12.6%', 'Rakan', 'Support', 35296, 0)
# ("['Audax']", "['9/3/5']", "['229']", '27.7%', '22.8%', 'Camille', 'Top', 35296, 0)
# ("['Cleanser']", "['4/4/14']", "['156']", '9.5%', '18.8%', 'Lee', 'Jungle', 35296, 0)
# ("['Beaupere']", "['4/3/11']", "['288']", '28.8%', '21.9%', 'Syndra', 'Mid', 35296, 0)
# ("['Rago44']", "['4/3/7']", "['309']", '29%', '23.3%', 'Ezreal', 'Adc', 35296, 0)
# ("['Lion']", "['2/4/10']", "['37']", '5.1%', '13.1%', 'Rell', 'Support', 35296, 0)
# ("['Adiss']", "['6/2/5']", "['194']", '30.7%', '24.1%', 'Sett', 'Top', 35295, 0)
# ("['Kenapil']", "['7/0/8']", "['139']", '15.7%', '20.6%', 'Jarvan', 'Jungle', 35295, 0)
# ("['Vladi']", "['1/4/7']", "['192']", '19.5%', '17.7%', 'Sylas', 'Mid', 35295, 0)
# ("['Gosberg']", "['8/3/4']", "['221']", '25.8%', '24%', 'Lucian', 'Adc', 35295, 0)
# ("['SPEEDOBEAR']", "['1/5/14']", "['14']", '8.3%', '13.6%', 'Nami', 'Support', 35295, 0)
# ("['Lotus']", "['0/4/7']", "['129']", '20.9%', '16.1%', 'Aatrox', 'Top', 35295, 0)
# ("['Fallen']", "['6/6/5']", "['128']", '22.9%', '21.4%', 'Viego', 'Jungle', 35295, 0)
# ("['Rogue']", "['1/4/4']", "['231']", '20.2%', '22.5%', 'Twisted', 'Mid', 35295, 0)
# ("['Kaba']", "['5/4/7']", "['234']", '27.4%', '26.7%', 'Kaisa', 'Adc', 35295, 0)
# ("['ZaFiR']", "['2/5/5']", "['32']", '8.5%', '13.4%', 'Nautilus', 'Support', 35295, 0)
# ("['Sleeping']", "['2/4/4']", "['246']", '19%', '20.6%', 'Aatrox', 'Top', 35321, 0)
# ("['Kadir']", "['1/4/8']", "['192']", '14.9%', '17.9%', 'Xin', 'Jungle', 35321, 0)
# ("['Decay']", "['8/2/6']", "['210']", '32.5%', '21.9%', 'LeBlanc', 'Mid', 35321, 0)
# ("['jinjo']", "['4/2/7']", "['294']", '28.8%', '26%', 'Aphelios', 'Adc', 35321, 0)
# ("['Dreamer', 'Ace']", "['1/4/11']", "['42']", '4.8%', '13.6%', 'Galio', 'Support', 35321, 0)
# ("['Satorius']", "['4/4/3']", "['185']", '23.2%', '20.2%', 'Sett', 'Top', 35321, 0)
# ("['Pridestalkr']", "['8/4/7']", "['238']", '30.3%', '25.3%', 'Zed', 'Jungle', 35321, 0)
# ("['Czekolad']", "['1/3/10']", "['258']", '20%', '20.4%', 'Lissandra', 'Mid', 35321, 0)
# ("['Gadget']", "['2/2/8']", "['269']", '19.2%', '21.4%', 'Miss', 'Adc', 35321, 0)
# ("['kamilius']", "['1/3/12']", "['23']", '7.3%', '12.8%', 'Rakan', 'Support', 35321, 0)
# ("['Sleeping']", "['9/4/5']", "['321']", '35.6%', '24.2%', 'Camille', 'Top', 35321, 1)
# ("['Kadir']", "['2/2/10']", "['181']", '12.3%', '15.9%', 'Xin', 'Jungle', 35321, 1)
# ("['Decay']", "['3/0/12']", "['341']", '17.3%', '21.7%', 'Orianna', 'Mid', 35321, 1)
# ("['jinjo']", "['6/1/10']", "['388']", '30.2%', '25.4%', 'Sivir', 'Adc', 35321, 1)
# ("['Dreamer', 'Ace']", "['1/2/13']", "['42']", '4.6%', '12.7%', 'Leona', 'Support', 35321, 1)
# ("['Satorius']", "['2/7/4']", "['171']", '16.1%', '15.7%', 'Sett', 'Top', 35321, 1)
# ("['Pridestalkr']", "['3/1/5']", "['368']", '26.3%', '26.5%', 'Graves', 'Jungle', 35321, 1)
# ("['Czekolad']", "['0/2/6']", "['354']", '27.5%', '22.4%', 'Azir', 'Mid', 35321, 1)
# ("['Gadget']", "['4/5/0']", "['323']", '24.9%', '24%', 'Karthus', 'Adc', 35321, 1)
# ("['kamilius']", "['0/6/5']", "['29']", '5.2%', '11.2%', 'Amumu', 'Support', 35321, 1)
# ("['Satorius']", "['1/5/4']", "['304']", '16.1%', '20.4%', 'Gragas', 'Top', 35321, 2)
# ("['Pridestalkr']", "['3/3/4']", "['277']", '17.2%', '21%', 'Graves', 'Jungle', 35321, 2)
# ("['Czekolad']", "['3/3/3']", "['347']", '39.7%', '25.7%', 'Corki', 'Mid', 35321, 2)
# ("['Gadget']", "['3/4/6']", "['307']", '22.8%', '21.3%', 'Miss', 'Adc', 35321, 2)
# ("['kamilius']", "['0/5/7']", "['37']", '4.2%', '11.6%', 'Leona', 'Support', 35321, 2)
# ("['Sleeping']", "['4/2/5']", "['322']", '20%', '22.7%', 'Camille', 'Top', 35321, 2)
# ("['Kadir']", "['2/2/10']", "['165']", '11.6%', '16.3%', 'Poppy', 'Jungle', 35321, 2)
# ("['Decay']", "['5/1/10']", "['306']", '25.9%', '21.3%', 'Sylas', 'Mid', 35321, 2)
# ("['jinjo']", "['8/1/7']", "['397']", '35.8%', '26.8%', 'Aphelios', 'Adc', 35321, 2)
# ("['Dreamer', 'Ace']", "['1/4/13']", "['49']", '6.7%', '13%', 'Galio', 'Support', 35321, 2)
# ("['Bako']", "['4/5/2']", "['284']", '37.1%', '24%', 'Jayce', 'Top', 35294, 0)
# ("['NikoleX']", "['2/7/3']", "['158']", '11.9%', '19.6%', 'Lee', 'Jungle', 35294, 0)
# ("['Peppe']", "['0/4/6']", "['226']", '19.9%', '20.9%', 'Twisted', 'Mid', 35294, 0)
# ("['Vaynedeta']", "['1/6/0']", "['280']", '24.4%', '22.6%', 'Aphelios', 'Adc', 35294, 0)
# ("['Sanity']", "['0/5/5']", "['42']", '6.8%', '12.9%', 'Thresh', 'Support', 35294, 0)
# ("['IceBreaker']", "['4/2/7']", "['243']", '16.5%', '19%', 'Wukong', 'Top', 35294, 0)
# ("['Carnage']", "['8/0/12']", "['204']", '18%', '19.8%', 'Trundle', 'Jungle', 35294, 0)
# ("['WaenA']", "['7/2/10']", "['316']", '22.3%', '23.1%', 'Sylas', 'Mid', 35294, 0)
# ("['Bananitoo']", "['8/2/8']", "['310']", '35.4%', '23.5%', 'Ziggs', 'Adc', 35294, 0)
# ("['iLevi']", "['0/1/21']", "['46']", '7.8%', '14.5%', 'Rakan', 'Support', 35294, 0)
# ("['Lotus']", "['0/4/9']", "['146']", '14.1%', '14.4%', 'Malphite', 'Top', 35292, 0)
# ("['Fallen']", "['9/1/7']", "['236']", '26.3%', '24.6%', 'Lillia', 'Jungle', 35292, 0)
# ("['Rogue']", "['2/5/4']", "['271']", '21.8%', '20.8%', 'Yone', 'Mid', 35292, 0)
# ("['Kaba']", "['7/5/7']", "['338']", '31.2%', '28%', 'Miss', 'Adc', 35292, 0)
# ("['ZaFiR']", "['0/8/10']", "['41']", '6.5%', '12.3%', 'Leona', 'Support', 35292, 0)
# ("['Tatuy']", "['4/3/9']", "['258']", '25.1%', '22.4%', 'Gwen', 'Top', 35292, 0)
# ("['Integral']", "['5/6/14']", "['162']", '19.5%', '18.2%', 'Lee', 'Jungle', 35292, 0)
# ("['Kourosh']", "['4/3/13']", "['241']", '18%', '23%', 'Twisted', 'Mid', 35292, 0)
# ("['Ralf']", "['8/2/11']", "['265']", '31.2%', '23.3%', 'Aphelios', 'Adc', 35292, 0)
# ("['SOAP']", "['2/4/16']", "['31']", '6.2%', '13%', 'Thresh', 'Support', 35292, 0)
# ("['Audax']", "['1/6/2']", "['253']", '17.6%', '21.4%', 'Graves', 'Top', 35291, 0)
# ("['Cleanser']", "['2/4/1']", "['176']", '7.8%', '20%', 'Viego', 'Jungle', 35291, 0)
# ("['Beaupere']", "['1/4/1']", "['303']", '26.7%', '22.8%', 'Syndra', 'Mid', 35291, 0)
# ("['Rago44']", "['0/4/2']", "['318']", '38.1%', '22.9%', 'Ezreal', 'Adc', 35291, 0)
# ("['Lion']", "['0/5/3']", "['38']", '9.8%', '12.9%', 'Nautilus', 'Support', 35291, 0)
# ("['Adiss']", "['4/1/9']", "['273']", '28.1%', '22.2%', 'Kennen', 'Top', 35291, 0)
# ("['Kenapil']", "['4/0/12']", "['176']", '15.7%', '17.9%', 'Lee', 'Jungle', 35291, 0)
# ("['Vladi']", "['9/2/6']", "['294']", '17.3%', '23.9%', 'Yasuo', 'Mid', 35291, 0)
# ("['Gosberg']", "['6/0/12']", "['313']", '32.6%', '23.9%', 'Miss', 'Adc', 35291, 0)
# ("['SPEEDOBEAR']", "['0/1/13']", "['39']", '6.2%', '12.2%', 'Bard', 'Support', 35291, 0)
# ("['IceBreaker']", "['0/3/4']", "['270']", '12.4%', '20.1%', 'Renekton', 'Top', 35288, 0)
# ("['Carnage']", "['1/5/8']", "['159']", '8.4%', '15.6%', 'Hecarim', 'Jungle', 35288, 0)
# ("['WaenA']", "['12/0/6']", "['256']", '44.5%', '24.8%', 'LeBlanc', 'Mid', 35288, 0)
# ("['Bananitoo']", "['8/1/3']", "['309']", '24.2%', '25.1%', 'Miss', 'Adc', 35288, 0)
# ("['iLevi']", "['1/1/17']", "['4']", '10.5%', '14.3%', 'Yuumi', 'Support', 35288, 0)
# ("['Audax']", "['3/2/4']", "['259']", '33.5%', '24.1%', 'Aatrox', 'Top', 35288, 0)
# ("['Cleanser']", "['1/2/8']", "['139']", '13.8%', '17.6%', 'Jarvan', 'Jungle', 35288, 0)
# ("['Beaupere']", "['5/6/4']", "['242']", '32.7%', '22.9%', 'Orianna', 'Mid', 35288, 0)
# ("['Rago44']", "['1/4/4']", "['292']", '15.8%', '23%', 'Lucian', 'Adc', 35288, 0)
# ("['Lion']", "['0/8/7']", "['17']", '4.2%', '12.4%', 'Nami', 'Support', 35288, 0)
# ("['WouLou']", "['1/0/7']", "['178']", '21.6%', '18.6%', 'Tahm', 'Top', 35287, 0)
# ("['Hatred']", "['2/1/6']", "['154']", '12.5%', '18.4%', 'Viego', 'Jungle', 35287, 0)
# ("['Tsiperakos']", "['3/2/5']", "['190']", '18.7%', '21%', 'Twisted', 'Mid', 35287, 0)
# ("['Druxy']", "['8/1/6']", "['284']", '40.7%', '28.1%', 'Miss', 'Adc', 35287, 0)
# ("['iDekap']", "['0/2/10']", "['36']", '6.4%', '13.9%', 'Thresh', 'Support', 35287, 0)
# ("['Tatuy']", "['2/3/2']", "['227']", '21.2%', '22.5%', 'Dr.', 'Top', 35287, 0)
# ("['Integral']", "['0/3/5']", "['140']", '13.4%', '18.2%', 'Lee', 'Jungle', 35287, 0)
# ("['Kourosh']", "['3/2/2']", "['216']", '16.4%', '24.5%', 'LeBlanc', 'Mid', 35287, 0)
# ("['Ralf']", "['1/3/2']", "['233']", '43.2%', '22%', 'Ezreal', 'Adc', 35287, 0)
# ("['SOAP']", "['0/3/3']", "['31']", '5.8%', '12.8%', 'Braum', 'Support', 35287, 0)
# ("['Rascal']", "['5/4/5']", "['339']", '17.3%', '21.1%', 'Kennen', 'Top', 35331, 0)
# ("['Clid']", "['4/2/12']", "['235']", '17.9%', '17.8%', 'Olaf', 'Jungle', 35331, 0)
# ("['Bdd']", "['5/1/6']", "['333']", '23.6%', '20.6%', 'Syndra', 'Mid', 35331, 0)
# ("['Ruler']", "['7/4/12']", "['438']", '25.6%', '26.2%', 'Miss', 'Adc', 35331, 0)
# ("['Life']", "['3/2/20']", "['5']", '15.5%', '14.3%', 'Yuumi', 'Support', 35331, 0)
# ("['Armut']", "['1/6/5']", "['408']", '12.6%', '22.1%', 'Irelia', 'Top', 35331, 0)
# ("['Elyoya']", "['0/5/9']", "['201']", '6.9%', '15.5%', 'Lee', 'Jungle', 35331, 0)
# ("['Humanoid']", "['6/5/4']", "['453']", '44.3%', '25.9%', 'Viktor', 'Mid', 35331, 0)
# ("['Carzzy']", "['6/5/6']", "['396']", '26.5%', '24.3%', 'Lucian', 'Adc', 35331, 0)
# ("['Kaiser']", "['0/3/9']", "['27']", '9.7%', '12.2%', 'Nami', 'Support', 35331, 0)
# ("['Armut']", "['4/6/7']", "['290']", '16.8%', '19.2%', 'Gnar', 'Top', 35330, 0)
# ("['Elyoya']", "['7/6/5']", "['297']", '18.1%', '20.8%', 'Qiyana', 'Jungle', 35330, 0)
# ("['Humanoid']", "['7/2/11']", "['383']", '31.2%', '23.4%', 'LeBlanc', 'Mid', 35330, 0)
# ("['Carzzy']", "['5/2/9']", "['406']", '30.9%', '23.9%', 'Ezreal', 'Adc', 35330, 0)
# ("['Kaiser']", "['0/3/14']", "['53']", '3.1%', '12.6%', 'Rakan', 'Support', 35330, 0)
# ("['Ale']", "['7/9/5']", "['298']", '31.1%', '21%', 'Kennen', 'Top', 35330, 0)
# ("['Tarzan']", "['2/3/6']", "['201']", '11.6%', '16.6%', 'Viego', 'Jungle', 35330, 0)
# ("['icon']", "['4/4/6']", "['362']", '13.1%', '21.3%', 'Ryze', 'Mid', 35330, 0)
# ("['Light']", "['5/1/5']", "['501']", '40.7%', '28.6%', 'Miss', 'Adc', 35330, 0)
# ("['Iwandy']", "['1/6/8']", "['43']", '3.4%', '12.4%', 'Leona', 'Support', 35330, 0)
# ("['Rascal']", "['3/1/3']", "['384']", '20.3%', '24.1%', 'Graves', 'Top', 35329, 0)
# ("['Clid']", "['2/3/5']", "['174']", '8.3%', '16.6%', 'Jarvan', 'Jungle', 35329, 0)
# ("['Bdd']", "['3/1/5']", "['314']", '30%', '20.4%', 'Zoe', 'Mid', 35329, 0)
# ("['Ruler']", "['5/0/3']", "['367']", '30.2%', '26%', 'Miss', 'Adc', 35329, 0)
# ("['Life']", "['1/0/9']", "['4']", '11.1%', '12.9%', 'Yuumi', 'Support', 35329, 0)
# ("['Alphari']", "['2/2/1']", "['341']", '37.7%', '25.1%', 'Jayce', 'Top', 35329, 0)
# ("['Santorin']", "['0/3/5']", "['158']", '12%', '16.4%', 'Xin', 'Jungle', 35329, 0)
# ("['Jensen']", "['1/2/3']", "['345']", '31%', '22.8%', 'Syndra', 'Mid', 35329, 0)
# ("['Tactical']", "['2/3/1']", "['328']", '13.1%', '23.6%', 'Tristana', 'Adc', 35329, 0)
# ("['CoreJJ']", "['0/4/4']", "['37']", '6.2%', '12.2%', 'Rell', 'Support', 35329, 0)
# ("['Ale']", "['2/3/0']", "['280']", '16.1%', '23.6%', 'Jax', 'Top', 35278, 0)
# ("['Tarzan']", "['1/3/3']", "['166']", '9.8%', '16.8%', 'Lee', 'Jungle', 35278, 0)
# ("['icon']", "['2/7/2']", "['251']", '10.8%', '23.1%', 'Irelia', 'Mid', 35278, 0)
# ("['Light']", "['2/2/4']", "['299']", '56.3%', '23.8%', 'Ziggs', 'Adc', 35278, 0)
# ("['Iwandy']", "['0/2/5']", "['43']", '7.1%', '12.7%', 'Leona', 'Support', 35278, 0)
# ("['Armut']", "['6/1/3']", "['291']", '29.1%', '22.9%', 'Gwen', 'Top', 35278, 0)
# ("['Elyoya']", "['3/2/10']", "['176']", '18.8%', '18.5%', 'Poppy', 'Jungle', 35278, 0)
# ("['Humanoid']", "['6/1/6']", "['315']", '25.2%', '25%', 'Orianna', 'Mid', 35278, 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-57ec57766a67> in <module>
# ----> 1 select_all_tasks(conn)
#
# <ipython-input-49-ced4d48fe3cc> in select_all_tasks(conn)
#       7
#       8     for row in rows:
# ----> 9         print(row)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
type(df_general['Match_id'].iloc[0])
# Out:
# numpy.int64
